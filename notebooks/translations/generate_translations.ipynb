# %%
import os
from dotenv import load_dotenv
load_dotenv() # API key comes from .env
import anthropic
import pandas as pd
import json
import tqdm

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ["GEMINI_API_KEY"])

# %%
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 8192,
  "response_mime_type": "application/json",
}
model = genai.GenerativeModel(
  model_name="gemini-1.5-pro",
  generation_config=generation_config,
)

# %%
#response = model.generate_content([
#  "input: Tõlgi järgnev vana-kreekakeelne lause ja märksõna eesti keelde. \nOle grammatiliselt originaalile nii lähedane, kui võimalik. Ära tee eesti keeles grammatikavigu. Samuti tõlgi eraldi sõnad. \n\nVäljund peab olema korrektne JSON objekt, kus peavad olema väljad: \n\"lause\" - eestikeelne tõlge\n\"märksõna\" - märksõna eestikeelne tõlge koos lemmaga. Lemma PEAB olema eestikeelne. (nt: loetav [lemma: lugema])\n\"tõlked\" - list iga sõna individuaalse tõlkega. Listi elemendid on objektid võtmetega \"grc\" - algne sõne ja \"ee\" - tõlge. Nendele tõlgetele EI PEA lisama lemmat. Kui kontekst seda nõuab, võib ühe sõna asemel tõlkida terve sõnapaari või kombinatsiooni.\nKui märksõna liik on (determiner), lisa tõlkesse (\"märksõna\" välja) LEMMA ASEMEL RUUTSULGUDE SISSE selle sugu ja kääne, kui võimalik, formaadis: \"nende (m. gen. pl.) [lemma: nemad]\".\n\n\"lause\" väljas võib semantilistele sõna või sõnapaari tõlkele järgneda otsetõlge (sulgude sees), kuid mitte \"tõlked\" väljas. \nOtsetõlke korral EI TOHI MITTE KUNAGI sulgudesse lisada midagi üleliigset, nagu märget \"sõna-sõnalt\" või vana-kreekakeelset algvarianti.\nKui lause tõlge sisaldab sõna, mida algses vana-kreekakeelses lauses ei esinenud, kasuta \"lause\" väljas selle sõna ümber [ruutsulge], kuid ürita selliseid olukordi vältida.\nTõlkides \"märksõna\", tõlgi lisaks märksõnale ka lemma. \n\nLähtu näidissisendist ja näidisväljundist.\n\n{\"märksõna\": \"πίνει [lemma: πίνω] (verb) | finite; present.active.indicative.third.singular\", \"lause\": \"καὶ αὐτὸς ἐκ τῆς τοῦ ἑτέρου πίνει.\", \"allikas\": \"histories by herodotus\", \"sõnad\": [\"καὶ [lemma: καί] (coordinating_conjunction)\", \"αὐτὸς [lemma: αὐτός] (adjective) | singular.masculine.nominative\", \"ἐκ [lemma: ἐκ] (adposition)\", \"τῆς [lemma: ὁ] (determiner) | singular.feminine.genitive\", \"τοῦ [lemma: ὁ] (determiner) | singular.masculine.genitive\", \"ἑτέρου [lemma: ἕτερος] (adjective) | singular.masculine.genitive\", \"πίνει [lemma: πίνω] (verb) | finite; present.active.indicative.third.singular\"]}",
#  "output: {\"lause\": \"Ja [tema] ise teise [karikast] joob.\", \"märksõna\": \"joob [lemma: jooma]\", \"tõlked\": [{\"grc\": \"καὶ\", \"ee\": \"ja\"}, {\"grc\": \"αὐτὸς\", \"ee\": \"ise\"}, {\"grc\": \"ἐκ τῆς τοῦ ἑτέρου\", \"ee\": \"teisest\"}, {\"grc\": \"πίνει\", \"ee\": \"joob\"}]}",
#  "input: {'märksõna': 'δὲ [lemma: δέ] (coordinating_conjunction)', 'lause': 'ἡ μὲν ἄπωθεν, ἡ δὲ πέλας·', 'allikas': 'Argonautica by apollonius rhodius', 'sõnad': ['ἡ [lemma: ὁ] (determiner) | singular.feminine.nominative', 'μὲν [lemma: μέν] (adverb)', 'ἄπωθεν [lemma: ἄπωθεν] (adverb)', 'ἡ [lemma: ὁ] (determiner) | singular.feminine.nominative', 'δὲ [lemma: δέ] (coordinating_conjunction)', 'πέλας [lemma: πέλας] (adverb)']}",
#  "output: ",
#])

# %%
from translation_utils import get_system_msg, get_user_prompt, parse_output, find_matching_sentences, sentence_to_prompt_input_dict, filter_matching_sentences, word_to_simple_identifier, PromptType

# %%
#client = anthropic.Anthropic()

# %%
prompt_dict = {
    "target": "πίνει [lemma: πίνω] (verb) | finite; present.active.indicative.third.singular",
    "phrase": "ὅ τε ἵππος αὐτοῖς κριθῆς μὲν οὐδʼ ὅλως γεύεται, ποηφαγῶν ἀεί, πίνει δὲ διὰ πολλοῦ.",
    "source": "Punic Wars by appianus of alexandria",
    "words": ["ὅ [lemma: ὁ] (determiner) | singular.masculine.nominative",
"τε [lemma: τε] (adverb)",
"ἵππος [lemma: ἵππος] (noun) | singular.feminine.nominative",
"αὐτοῖς [lemma: αὐτός] (pronoun) | plural.masculine.dative",
"κριθῆς [lemma: κριθή] (adjective) | singular.neuter.genitive",
"μὲν [lemma: μέν] (adverb)",
"οὐδʼ [lemma: οὐδʼ] (adverb)",
"ὅλως [lemma: ὅλος] (adverb)",
"γεύεται [lemma: γεύεται] (verb) | finite; present.middle.subjunctive.third.plural",
"ποηφαγῶν [lemma: ποηφαγέω] (verb) | participle; present.active.singular.nominative",
"ἀεί [lemma: ἀεί] (adverb)",
"πίνει [lemma: πίνω] (verb) | finite; past.active.indicative.third.singular",
"δὲ [lemma: δέ] (particle)",
"διὰ [lemma: διά] (adposition)",
"πολλοῦ [lemma: πολύς] (adjective) | singular.neuter.genitive",]
}
print(json.dumps(prompt_dict, ensure_ascii=False))
# Out:
# {"target": "πίνει [lemma: πίνω] (verb) | finite; present.active.indicative.third.singular", "phrase": "ὅ τε ἵππος αὐτοῖς κριθῆς μὲν οὐδʼ ὅλως γεύεται, ποηφαγῶν ἀεί, πίνει δὲ διὰ πολλοῦ.", "source": "Punic Wars by appianus of alexandria", "words": ["ὅ [lemma: ὁ] (determiner) | singular.masculine.nominative", "τε [lemma: τε] (adverb)", "ἵππος [lemma: ἵππος] (noun) | singular.feminine.nominative", "αὐτοῖς [lemma: αὐτός] (pronoun) | plural.masculine.dative", "κριθῆς [lemma: κριθή] (adjective) | singular.neuter.genitive", "μὲν [lemma: μέν] (adverb)", "οὐδʼ [lemma: οὐδʼ] (adverb)", "ὅλως [lemma: ὅλος] (adverb)", "γεύεται [lemma: γεύεται] (verb) | finite; present.middle.subjunctive.third.plural", "ποηφαγῶν [lemma: ποηφαγέω] (verb) | participle; present.active.singular.nominative", "ἀεί [lemma: ἀεί] (adverb)", "πίνει [lemma: πίνω] (verb) | finite; past.active.indicative.third.singular", "δὲ [lemma: δέ] (particle)", "διὰ [lemma: διά] (adposition)", "πολλοῦ [lemma: πολύς] (adjective) | singular.neuter.genitive"]}

# %%
df_sents = pd.read_parquet("../../data/sentences.parquet").drop_duplicates(subset=["sentence_txt"]).reset_index().rename(columns={"index": "grc_sent_idx"}).set_index(["grc_sent_idx"])
df_sents["ee_sent_idx"] = None

# %%
df_words = pd.read_parquet("../../data/word_to_lemma.parquet").reset_index().rename(columns={"level_0": "grc_target_idx"}).set_index(["grc_target_idx"])
df_words["ee_sent_idx"] = None

# %%
df_sents_ee = pd.DataFrame(columns=['ee_sent_idx', "ee_phrase", "ee_target", "ee_words", "grc_sent_idx", "grc_target_idx"]).set_index("ee_sent_idx")

# %%
chosenSentence = df_sents[df_sents.sentence_txt == "καὶ αὐτὸς ἐκ τῆς τοῦ ἑτέρου πίνει."].iloc[0]
def findTarget(w_str: str, sentence: dict):
    return [w for w in sentence.sentence_obj if w["string"] == w_str][0]
example_input_dict = sentence_to_prompt_input_dict(
    row=chosenSentence,
    targetWord=word_to_simple_identifier(findTarget("πίνει", chosenSentence))
)

# %%
chosenSentence = df_sents[df_sents.sentence_txt == "ὅ τε ἵππος αὐτοῖς κριθῆς μὲν οὐδʼ ὅλως γεύεται, ποηφαγῶν ἀεί, πίνει δὲ διὰ πολλοῦ."].iloc[0]
example_input_dict = sentence_to_prompt_input_dict(
    row=chosenSentence,
    targetWord=word_to_simple_identifier(findTarget("πίνει", chosenSentence))
)

# %%
example_input_dict
# Out:
# {'märksõna': 'πίνει [lemma: πίνω] (verb) | finite; past.active.indicative.third.singular',
#  'lause': 'ὅ τε ἵππος αὐτοῖς κριθῆς μὲν οὐδʼ ὅλως γεύεται, ποηφαγῶν ἀεί, πίνει δὲ διὰ πολλοῦ.',
#  'allikas': 'Punic Wars by appianus of alexandria',
#  'sõnad': ['ὅ [lemma: ὁ] (determiner) | singular.masculine.nominative',
#   'τε [lemma: τε] (adverb)',
#   'ἵππος [lemma: ἵππος] (noun) | singular.feminine.nominative',
#   'αὐτοῖς [lemma: αὐτός] (pronoun) | plural.masculine.dative',
#   'κριθῆς [lemma: κριθή] (adjective) | singular.neuter.genitive',
#   'μὲν [lemma: μέν] (adverb)',
#   'οὐδʼ [lemma: οὐδʼ] (adverb)',
#   'ὅλως [lemma: ὅλος] (adverb)',
#   'γεύεται [lemma: γεύεται] (verb) | finite; present.middle.subjunctive.third.plural',
#   'ποηφαγῶν [lemma: ποηφαγέω] (verb) | participle; present.active.singular.nominative',
#   'ἀεί [lemma: ἀεί] (adverb)',
#   'πίνει [lemma: πίνω] (verb) | finite; past.active.indicative.third.singular',
#   'δὲ [lemma: δέ] (particle)',
#   'διὰ [lemma: διά] (adposition)',
#   'πολλοῦ [lemma: πολύς] (adjective) | singular.neuter.genitive']}

# %%
get_system_msg(PromptType.GEMINI)
# Out:
# ['instruction: Tõlgi järgnev vana-kreekakeelne lause ja märksõna eesti keelde. \nOle grammatiliselt originaalile nii lähedane, kui võimalik. Ära tee eesti keeles grammatikavigu. Samuti tõlgi eraldi sõnad. \n\nVäljund peab olema korrektne JSON objekt, kus peavad olema väljad: \n"lause" - eestikeelne tõlge\n"märksõna" - märksõna eestikeelne tõlge koos lemmaga. Lemma PEAB olema eestikeelne. (nt: loetav [lemma: lugema])\n"tõlked" - list iga sõna individuaalse tõlkega. Listi elemendid on objektid võtmetega "grc" - algne sõne ja "ee" - tõlge. Nendele tõlgetele EI PEA lisama lemmat. Kui kontekst seda nõuab, võib ühe sõna asemel tõlkida terve sõnapaari või kombinatsiooni.\nKui märksõna liik on (determiner), lisa tõlkesse ("märksõna" välja) LEMMA ASEMEL RUUTSULGUDE SISSE selle sugu ja kääne, kui võimalik, formaadis: "nende (m. gen. pl.) [lemma: nemad]".\n\n"lause" väljas võib semantilistele sõna või sõnapaari tõlkele järgneda otsetõlge (sulgude sees), kuid mitte "tõlked" väljas. \nOtsetõlke korral EI TOHI MITTE KUNAGI sulgudesse lisada midagi üleliigset, nagu märget "sõna-sõnalt" või vana-kreekakeelset algvarianti.\nKui lause tõlge sisaldab sõna, mida algses vana-kreekakeelses lauses ei esinenud, kasuta "lause" väljas selle sõna ümber [ruutsulge], kuid ürita selliseid olukordi vältida.\nTõlkides "märksõna", tõlgi lisaks märksõnale ka lemma. \n\nLähtu näidissisendist ja näidisväljundist.',
#  'input: {"märksõna": "πίνει [lemma: πίνω] (verb) | finite; present.active.indicative.third.singular", "lause": "καὶ αὐτὸς ἐκ τῆς τοῦ ἑτέρου πίνει.", "allikas": "histories by herodotus", "sõnad": ["καὶ [lemma: καί] (coordinating_conjunction)", "αὐτὸς [lemma: αὐτός] (adjective) | singular.masculine.nominative", "ἐκ [lemma: ἐκ] (adposition)", "τῆς [lemma: ὁ] (determiner) | singular.feminine.genitive", "τοῦ [lemma: ὁ] (determiner) | singular.masculine.genitive", "ἑτέρου [lemma: ἕτερος] (adjective) | singular.masculine.genitive", "πίνει [lemma: πίνω] (verb) | finite; present.active.indicative.third.singular"]}',
#  'output: {"lause": "Ja [tema] ise teise [karikast] joob.", "märksõna": "joob [lemma: jooma]", "tõlked": [{"grc": "καὶ", "ee": "ja"}, {"grc": "αὐτὸς", "ee": "ise"}, {"grc": "ἐκ τῆς τοῦ ἑτέρου", "ee": "teisest"}, {"grc": "πίνει", "ee": "joob"}]}']

# %%
get_user_prompt(example_input_dict, PromptType.GEMINI)
# Out:
# ["input: {'märksõna': 'πίνει [lemma: πίνω] (verb) | finite; past.active.indicative.third.singular', 'lause': 'ὅ τε ἵππος αὐτοῖς κριθῆς μὲν οὐδʼ ὅλως γεύεται, ποηφαγῶν ἀεί, πίνει δὲ διὰ πολλοῦ.', 'allikas': 'Punic Wars by appianus of alexandria', 'sõnad': ['ὅ [lemma: ὁ] (determiner) | singular.masculine.nominative', 'τε [lemma: τε] (adverb)', 'ἵππος [lemma: ἵππος] (noun) | singular.feminine.nominative', 'αὐτοῖς [lemma: αὐτός] (pronoun) | plural.masculine.dative', 'κριθῆς [lemma: κριθή] (adjective) | singular.neuter.genitive', 'μὲν [lemma: μέν] (adverb)', 'οὐδʼ [lemma: οὐδʼ] (adverb)', 'ὅλως [lemma: ὅλος] (adverb)', 'γεύεται [lemma: γεύεται] (verb) | finite; present.middle.subjunctive.third.plural', 'ποηφαγῶν [lemma: ποηφαγέω] (verb) | participle; present.active.singular.nominative', 'ἀεί [lemma: ἀεί] (adverb)', 'πίνει [lemma: πίνω] (verb) | finite; past.active.indicative.third.singular', 'δὲ [lemma: δέ] (particle)', 'διὰ [lemma: διά] (adposition)', 'πολλοῦ [lemma: πολύς] (adjective) | singular.neuter.genitive']}",
#  'output: ']

# %%
def get_translation_gemini(model: genai.GenerativeModel, greek_sentence_dict: dict):
    response = model.generate_content(get_system_msg(PromptType.GEMINI) + get_user_prompt(greek_sentence_dict, PromptType.GEMINI))
    return response
def get_translation_anthropic(client: anthropic.Anthropic, greek_sentence_dict: dict) -> anthropic.types.message.Message:
    #print(get_system_msg())
    #print(get_user_prompt(greek_sentence_dict))
    #return None
    message = client.messages.create(
        model="claude-3-opus-20240229",
        max_tokens=1024,
        system=get_system_msg(),
        messages=[
            {"role": "user", "content": get_user_prompt(greek_sentence_dict)}
        ]
    )
    return message

# %%
df_sents_ee.head()
# Out:
# Empty DataFrame
# Columns: [ee_phrase, ee_target, ee_words, grc_sent_idx, grc_target_idx]
# Index: []

# %%
df_words.head()
# Out:
#                                                             index text  count  \
# grc_target_idx
# 1                     καὶ [lemma: καί] (coordinating_conjunction)  καὶ  76985
# 4                                         δὲ [lemma: δέ] (adverb)   δὲ  26946
# 5                                       καὶ [lemma: καί] (adverb)  καὶ  21000
# 6               τὴν [lemma: ὁ] (determiner) | singular.feminin...  τὴν  19781
# 7                                     ἐν [lemma: ἐν] (adposition)   ἐν  19662
#
#                lemma                       pos Aspect        Case  \
# grc_target_idx
# 1                καί  coordinating_conjunction   None        None
# 4                 δέ                    adverb   None        None
# 5                καί                    adverb   None        None
# 6                  ὁ                determiner   None  accusative
# 7                 ἐν                adposition   None        None
#
#                Definiteness Degree    Gender  ...    Number Person Polarity  \
# grc_target_idx                                ...
# 1                      None   None      None  ...      None   None     None
# 4                      None   None      None  ...      None   None     None
# 5                      None   None      None  ...      None   None     None
# 6                      None   None  feminine  ...  singular   None     None
# 7                      None   None      None  ...      None   None     None
#
#                Possessive PronominalType Reflexive Tense VerbForm Voice  \
# grc_target_idx
# 1                    None           None      None  None     None  None
# 4                    None           None      None  None     None  None
# 5                    None           None      None  None     None  None
# 6                    None           None      None  None     None  None
# 7                    None           None      None  None     None  None
#
#                ee_sent_idx
# grc_target_idx
# 1                     None
# 4                     None
# 5                     None
# 6                     None
# 7                     None
#
# [5 rows x 21 columns]

# %%
df_sents
# Out:
#                                                        metadata  \
# grc_sent_idx
# 0             {'author': 'lysias', 'edition': 'Lysias with a...
# 1             {'author': 'lysias', 'edition': 'Lysias with a...
# 2             {'author': 'lysias', 'edition': 'Lysias with a...
# 3             {'author': 'lysias', 'edition': 'Lysias with a...
# 4             {'author': 'lysias', 'edition': 'Lysias with a...
# ...                                                         ...
# 134639        {'author': 'homeric hymns', 'edition': 'Hymni ...
# 134640        {'author': 'homeric hymns', 'edition': 'Hymni ...
# 134641        {'author': 'homeric hymns', 'edition': 'Hymni ...
# 134642        {'author': 'homeric hymns', 'edition': 'Hymni ...
# 134643        {'author': 'homeric hymns', 'edition': 'Hymni ...
#
#                                                    sentence_obj  \
# grc_sent_idx
# 0             [{'category': {'F': 'neg', 'N': 'pos', 'V': 'p...
# 1             [{'category': {'F': 'pos', 'N': 'pos', 'V': 'n...
# 2             [{'category': {'F': 'neg', 'N': 'neg', 'V': 'p...
# 3             [{'category': {'F': 'pos', 'N': 'neg', 'V': 'n...
# 4             [{'category': {'F': 'neg', 'N': 'neg', 'V': 'p...
# ...                                                         ...
# 134639        [{'category': {'F': 'neg', 'N': 'pos', 'V': 'p...
# 134640        [{'category': {'F': 'pos', 'N': 'pos', 'V': 'n...
# 134641        [{'category': {'F': 'pos', 'N': 'neg', 'V': 'n...
# 134642        [{'category': {'F': 'pos', 'N': None, 'V': Non...
# 134643        [{'category': {'F': 'neg', 'N': 'pos', 'V': 'p...
#
#                                                    sentence_txt  len_words  \
# grc_sent_idx
# 0             ἴσως τινὲς ὑμῶν, ὦ ἄνδρες δικασταί, διὰ τὸ βού...         23
# 1             ἐγὼ δὲ τοσούτου δέω περὶ τῶν μὴ, προσηκόντων ἱ...         31
# 2             οἴμαι μὲν οὖν, ἐάν πάντα διηγήσωμαι τὰ πεπραγμ...         30
# 3                                        ἐξ ἀρχῆς οὖν ἀκούσατε.          5
# 4             ἐράτων ὁ Ἐρασιφῶντος πατὴρ ἐδανείσατο παρὰ τοῦ...         12
# ...                                                         ...        ...
# 134639        αἰδοίην, χρυσοστέφανον, καλὴν Ἀφροδίτην ᾁσομαι...         30
# 134640        τὴν δὲ χρυσάμπυκες Ὧραι δέξαντ ̓ ἀσπασίως, περ...         28
# 134641        ἐν δὲ τρητοῖσι λοβοῖσιν ἄνθεμ ̓ ὀρειχάλκου χρυ...         42
# 134642        αὐτὰρ ἐπειδὴ πάντα περὶ χροῒ κόσμον ἔθηκαν, ἦγ...         37
# 134643        χαῖρ ̓ ἑλικοβλέφαρε, γλυκυμείλιχε : δὸς δ ̓ ἐν...         21
#
#               len_chars ee_sent_idx
# grc_sent_idx
# 0                   120        None
# 1                   150        None
# 2                   172        None
# 3                    22        None
# 4                    71        None
# ...                 ...         ...
# 134639              184        None
# 134640              140        None
# 134641              242        None
# 134642              214        None
# 134643               98        None
#
# [121104 rows x 6 columns]

# %%
def save_output(df_sents_ee: pd.DataFrame, df_sents_grc: pd.DataFrame, df_words: pd.DataFrame, grc_sent_idx: int, grc_target_idx: int, parsed_msg_output: dict):
    ee_sent_idx = len(df_sents_ee)
    row = {
        # "sent_idx": ee_sent_idx,
        "ee_phrase": parsed_msg_output["lause"],
        "ee_target": parsed_msg_output["märksõna"],
        "ee_words": parsed_msg_output["tõlked"],
        "grc_sent_idx": grc_sent_idx,
        "grc_target_idx": grc_target_idx
    }
    df_sents_ee.loc[ee_sent_idx] = row
    df_sents_grc.loc[grc_sent_idx, "ee_sent_idx"] = ee_sent_idx
    df_words.loc[grc_target_idx, "ee_sent_idx"] = ee_sent_idx

# save_output(grc_sent_idx, grc_target_idx, output)

# %%
def extract_response_gemini(response):
    return dict(json.loads(response.text))
def extract_response_anthropic(message: anthropic.types.message.Message):
    return dict(json.loads(message.content[0].text))

# %%
def persist_tables(df_sents_grc: pd.DataFrame, df_words: pd.DataFrame, df_sents_ee: pd.DataFrame, persist_all=False) -> None:
    df_sents_ee.to_parquet("ee_sentences.parquet")
    if persist_all:
        df_sents_grc.to_parquet("grc_sentences.parquet")
        df_words.to_parquet("grc_words.parquet")

# %%
if all(not os.path.exists(path) for path in ["ee_sentences.parquet", "grc_sentences.parquet", "grc_words.parquet"]):
    persist_tables(df_sents, df_words, df_sents_ee, persist_all=True)

if os.path.exists("ee_sentences.parquet"):
    df_sents_ee = pd.read_parquet("ee_sentences.parquet")
if os.path.exists("grc_sentences.parquet"):
    df_sents = pd.read_parquet("grc_sentences.parquet")
if os.path.exists("grc_words.parquet"):
    df_words = pd.read_parquet("grc_words.parquet")

# %%
LENGTH_THRESHOLD = 501 # because of API limits
i = -1
for grc_target_idx, w in df_words.sort_values(by="count", ascending=False).iterrows():
    # print(i, w)
    i += 1
    print()
    if len(df_sents_ee) > LENGTH_THRESHOLD:
        break
    target_word = w.to_dict()
    target_word_str = target_word["index"]
    print(i, target_word_str) #, wd["grc_target_idx"])
    if sum(df_sents_ee.grc_target_idx == grc_target_idx) > 0: # already generated
        print(f"Sentence already generated for word {target_word['index']}, skipping")
        continue
    # print(target_word)
    matches = find_matching_sentences(df_sents, target_word, sortby=[])
    # print(f"Pre-filter found {len(matches)} matches")
    filtered_matches = filter_matching_sentences(matches, min_words=4, max_words=10, topk=5).drop_duplicates(subset="sentence_txt", keep="last")
    if len(filtered_matches) == 0:
        print(f"No matches found for word {target_word['index']}, skipping")
        continue
    selected_sentence = filtered_matches.iloc[0]    
    grc_sent_idx = selected_sentence.name
    print(selected_sentence.sentence_txt)
    # get translation
    try:
        input_dict = sentence_to_prompt_input_dict(
            row=selected_sentence.to_dict(),
            targetWord=target_word_str
        )
        response = get_translation_gemini(model, input_dict) # get_translation_anthropic(client, input_dict)
        parsed_output = extract_response_gemini(response)
        print(parsed_output)
        save_output(df_sents_ee=df_sents_ee, df_sents_grc=df_sents, df_words=df_words, grc_sent_idx=grc_sent_idx, grc_target_idx=grc_target_idx, parsed_msg_output=parsed_output)
        persist_tables(df_sents, df_words, df_sents_ee)
    except Exception as e:
        print(f"Could not translate sentence {grc_sent_idx}; {e}")
        continue
# Out:
# 0 καὶ [lemma: καί] (coordinating_conjunction)
# Sentence already generated for word καὶ [lemma: καί] (coordinating_conjunction), skipping
#
# 1 δὲ [lemma: δέ] (adverb)
# Sentence already generated for word δὲ [lemma: δέ] (adverb), skipping
#
# 2 καὶ [lemma: καί] (adverb)
# Sentence already generated for word καὶ [lemma: καί] (adverb), skipping
#
# 3 τὴν [lemma: ὁ] (determiner) | singular.feminine.accusative
# Sentence already generated for word τὴν [lemma: ὁ] (determiner) | singular.feminine.accusative, skipping
#
# 4 ἐν [lemma: ἐν] (adposition)
# Sentence already generated for word ἐν [lemma: ἐν] (adposition), skipping
#
# 5 ὁ [lemma: ὁ] (determiner) | singular.masculine.nominative
# Sentence already generated for word ὁ [lemma: ὁ] (determiner) | singular.masculine.nominative, skipping
#
# 6 μὲν [lemma: μέν] (adverb)
# Sentence already generated for word μὲν [lemma: μέν] (adverb), skipping
#
# 7 τῶν [lemma: ὁ] (determiner) | plural.masculine.genitive
# Sentence already generated for word τῶν [lemma: ὁ] (determiner) | plural.masculine.genitive, skipping
#
# 8 τὸν [lemma: ὁ] (determiner) | singular.masculine.accusative
# Sentence already generated for word τὸν [lemma: ὁ] (determiner) | singular.masculine.accusative, skipping
#
# 9 τῆς [lemma: ὁ] (determiner) | singular.feminine.genitive
# Sentence already generated for word τῆς [lemma: ὁ] (determiner) | singular.feminine.genitive, skipping
#
# 10 τοῦ [lemma: ὁ] (determiner) | singular.masculine.genitive
# Sentence already generated for word τοῦ [lemma: ὁ] (determiner) | singular.masculine.genitive, skipping
#
# 11 δὲ [lemma: δέ] (coordinating_conjunction)
# Sentence already generated for word δὲ [lemma: δέ] (coordinating_conjunction), skipping
#
# 12 τὸ [lemma: ὁ] (determiner) | singular.neuter.accusative
# τὸ ἑαυτὸν ἄρα γιγνώσκειν ἐστὶ σωφρονεῖν ;
# {'lause': 'Seega iseennast tunda on mõistlik olla (σωφρονεῖν).', 'märksõna': 'See (s. acc.) [lemma: see]', 'tõlked': [{'grc': 'τὸ', 'ee': 'See'}, {'grc': 'ἑαυτὸν', 'ee': 'iseennast'}, {'grc': 'ἄρα', 'ee': 'seega'}, {'grc': 'γιγνώσκειν', 'ee': 'tunda'}, {'grc': 'ἐστὶ', 'ee': 'on'}, {'grc': 'σωφρονεῖν', 'ee': 'mõistlik olla'}]}
#
# 13 τοὺς [lemma: ὁ] (determiner) | plural.masculine.accusative
# Sentence already generated for word τοὺς [lemma: ὁ] (determiner) | plural.masculine.accusative, skipping
#
# 14 οἱ [lemma: ὁ] (determiner) | plural.masculine.nominative
# Sentence already generated for word οἱ [lemma: ὁ] (determiner) | plural.masculine.nominative, skipping
#
# 15 ἐς [lemma: εἰς] (adposition)
# Sentence already generated for word ἐς [lemma: εἰς] (adposition), skipping
#
# 16 τὰ [lemma: ὁ] (determiner) | plural.neuter.accusative
# Sentence already generated for word τὰ [lemma: ὁ] (determiner) | plural.neuter.accusative, skipping
#
# 17 ἐπὶ [lemma: ἐπί] (adposition)
# Sentence already generated for word ἐπὶ [lemma: ἐπί] (adposition), skipping
#
# 18 δὲ [lemma: δέ] (particle)
# Sentence already generated for word δὲ [lemma: δέ] (particle), skipping
#
# 19 τῷ [lemma: ὁ] (determiner) | singular.masculine.dative
# Sentence already generated for word τῷ [lemma: ὁ] (determiner) | singular.masculine.dative, skipping
#
# 20 τοῖς [lemma: ὁ] (determiner) | plural.masculine.dative
# Sentence already generated for word τοῖς [lemma: ὁ] (determiner) | plural.masculine.dative, skipping
#
# 21 πρὸς [lemma: πρός] (adposition)
# Sentence already generated for word πρὸς [lemma: πρός] (adposition), skipping
#
# 22 οὐ [lemma: οὐ] (adverb)
# Sentence already generated for word οὐ [lemma: οὐ] (adverb), skipping
#
# 23 γὰρ [lemma: γάρ] (adverb)
# Sentence already generated for word γὰρ [lemma: γάρ] (adverb), skipping
#
# 24 οὐκ [lemma: οὐ] (adverb)
# Sentence already generated for word οὐκ [lemma: οὐ] (adverb), skipping
#
# 25 ἢ [lemma: ἤ] (coordinating_conjunction)
# Sentence already generated for word ἢ [lemma: ἤ] (coordinating_conjunction), skipping
#
# 26 εἰς [lemma: εἰς] (adposition)
# Sentence already generated for word εἰς [lemma: εἰς] (adposition), skipping
#
# 27 περὶ [lemma: περί] (adposition)
# Sentence already generated for word περὶ [lemma: περί] (adposition), skipping
#
# 28 τῇ [lemma: ὁ] (determiner) | singular.feminine.dative
# Sentence already generated for word τῇ [lemma: ὁ] (determiner) | singular.feminine.dative, skipping
#
# 29 τὸ [lemma: ὁ] (determiner) | singular.neuter.nominative
# Sentence already generated for word τὸ [lemma: ὁ] (determiner) | singular.neuter.nominative, skipping
#
# 30 ἐκ [lemma: ἐκ] (adposition)
# Sentence already generated for word ἐκ [lemma: ἐκ] (adposition), skipping
#
# 31 ὅτι [lemma: ὅτι] (subordinating_conjunction)
# Sentence already generated for word ὅτι [lemma: ὅτι] (subordinating_conjunction), skipping
#
# 32 εἶναι [lemma: εἰμί] (auxiliary) | infinitive; present.active
# Sentence already generated for word εἶναι [lemma: εἰμί] (auxiliary) | infinitive; present.active, skipping
#
# 33 τε [lemma: τε] (particle)
# Sentence already generated for word τε [lemma: τε] (particle), skipping
#
# 34 τε [lemma: τε] (adverb)
# Sentence already generated for word τε [lemma: τε] (adverb), skipping
#
# 35 ἡ [lemma: ὁ] (determiner) | singular.feminine.nominative
# Sentence already generated for word ἡ [lemma: ὁ] (determiner) | singular.feminine.nominative, skipping
#
# 36 ἂν [lemma: ἄν] (adverb)
# Sentence already generated for word ἂν [lemma: ἄν] (adverb), skipping
#
# 37 μὲν [lemma: μέν] (particle)
# Sentence already generated for word μὲν [lemma: μέν] (particle), skipping
#
# 38 ὡς [lemma: ὡς] (adverb)
# Sentence already generated for word ὡς [lemma: ὡς] (adverb), skipping
#
# 39 ὡς [lemma: ὡς] (subordinating_conjunction)
# καί σφεας ὡς ἴδεν ἆσσον, ἀνίαχεν·
# {'lause': 'Ja kui ta neid lähedalt nägi, siis [ta] ründas.', 'märksõna': 'kui [lemma: kui]', 'tõlked': [{'grc': 'καί', 'ee': 'ja'}, {'grc': 'σφεας', 'ee': 'neid'}, {'grc': 'ὡς', 'ee': 'kui'}, {'grc': 'ἴδεν', 'ee': 'nägi'}, {'grc': 'ἆσσον', 'ee': 'lähedalt'}, {'grc': 'ἀνίαχεν', 'ee': 'ründas'}]}
#
# 40 εἰ [lemma: εἰ] (subordinating_conjunction)
# Sentence already generated for word εἰ [lemma: εἰ] (subordinating_conjunction), skipping
#
# 41 τὰς [lemma: ὁ] (determiner) | plural.feminine.accusative
# Sentence already generated for word τὰς [lemma: ὁ] (determiner) | plural.feminine.accusative, skipping
#
# 42 γὰρ [lemma: γάρ] (particle)
# Sentence already generated for word γὰρ [lemma: γάρ] (particle), skipping
#
# 43 τε [lemma: τε] (coordinating_conjunction)
# Sentence already generated for word τε [lemma: τε] (coordinating_conjunction), skipping
#
# 44 κατὰ [lemma: κατά] (adposition)
# Sentence already generated for word κατὰ [lemma: κατά] (adposition), skipping
#
# 45 δὴ [lemma: δή] (adverb)
# Sentence already generated for word δὴ [lemma: δή] (adverb), skipping
#
# 46 ἦν [lemma: εἰμί] (auxiliary) | finite; past.active.indicative.third.singular
# Sentence already generated for word ἦν [lemma: εἰμί] (auxiliary) | finite; past.active.indicative.third.singular, skipping
#
# 47 ὦ [lemma: ὦ] (interjection)
# Sentence already generated for word ὦ [lemma: ὦ] (interjection), skipping
#
# 48 ὑπὸ [lemma: ὑπό] (adposition)
# Sentence already generated for word ὑπὸ [lemma: ὑπό] (adposition), skipping
#
# 49 δʼ [lemma: δʼ] (adverb)
# Sentence already generated for word δʼ [lemma: δʼ] (adverb), skipping
#
# 50 μὴ [lemma: μή] (adverb)
# Sentence already generated for word μὴ [lemma: μή] (adverb), skipping
#
# 51 τῶν [lemma: ὁ] (determiner) | plural.neuter.genitive
# Sentence already generated for word τῶν [lemma: ὁ] (determiner) | plural.neuter.genitive, skipping
#
# 52 διὰ [lemma: διά] (adposition)
# Sentence already generated for word διὰ [lemma: διά] (adposition), skipping
#
# 53 ἀλλὰ [lemma: ἀλλά] (coordinating_conjunction)
# Sentence already generated for word ἀλλὰ [lemma: ἀλλά] (coordinating_conjunction), skipping
#
# 54 ἀπὸ [lemma: ἀπό] (adposition)
# Sentence already generated for word ἀπὸ [lemma: ἀπό] (adposition), skipping
#
# 55 ἔφη [lemma: φημί] (verb) | finite; past.active.indicative.third.singular
# Sentence already generated for word ἔφη [lemma: φημί] (verb) | finite; past.active.indicative.third.singular, skipping
#
# 56 οὖν [lemma: οὖν] (adverb)
# Sentence already generated for word οὖν [lemma: οὖν] (adverb), skipping
#
# 57 αὐτοῦ [lemma: αὐτός] (pronoun) | singular.masculine.genitive
# Sentence already generated for word αὐτοῦ [lemma: αὐτός] (pronoun) | singular.masculine.genitive, skipping
#
# 58 νῦν [lemma: νῦν] (adverb)
# Sentence already generated for word νῦν [lemma: νῦν] (adverb), skipping
#
# 59 μοι [lemma: ἐγώ] (pronoun) | singular.masculine.dative
# Sentence already generated for word μοι [lemma: ἐγώ] (pronoun) | singular.masculine.dative, skipping
#
# 60 δʼ [lemma: δʼ] (adjective) | plural.neuter.accusative
# Sentence already generated for word δʼ [lemma: δʼ] (adjective) | plural.neuter.accusative, skipping
#
# 61 ἔτι [lemma: ἔτι] (adverb)
# Sentence already generated for word ἔτι [lemma: ἔτι] (adverb), skipping
#
# 62 αὐτῶν [lemma: αὐτός] (pronoun) | plural.masculine.genitive
# Sentence already generated for word αὐτῶν [lemma: αὐτός] (pronoun) | plural.masculine.genitive, skipping
#
# 63 παρὰ [lemma: παρά] (adposition)
# Sentence already generated for word παρὰ [lemma: παρά] (adposition), skipping
#
# 64 ταῦτα [lemma: οὗτος] (pronoun) | plural.neuter.accusative
# Sentence already generated for word ταῦτα [lemma: οὗτος] (pronoun) | plural.neuter.accusative, skipping
#
# 65 τι [lemma: τις] (pronoun) | singular.neuter.accusative
# Sentence already generated for word τι [lemma: τις] (pronoun) | singular.neuter.accusative, skipping
#
# 66 αὐτῷ [lemma: αὐτός] (pronoun) | singular.masculine.dative
# Sentence already generated for word αὐτῷ [lemma: αὐτός] (pronoun) | singular.masculine.dative, skipping
#
# 67 μετὰ [lemma: μετά] (adposition)
# Sentence already generated for word μετὰ [lemma: μετά] (adposition), skipping
#
# 68 τί [lemma: τίς] (pronoun) | singular.neuter.accusative
# Sentence already generated for word τί [lemma: τίς] (pronoun) | singular.neuter.accusative, skipping
#
# 69 αὐτοῖς [lemma: αὐτός] (pronoun) | plural.masculine.dative
# Sentence already generated for word αὐτοῖς [lemma: αὐτός] (pronoun) | plural.masculine.dative, skipping
#
# 70 ἐστιν [lemma: εἰμί] (auxiliary) | finite; present.active.indicative.third.singular
# Sentence already generated for word ἐστιν [lemma: εἰμί] (auxiliary) | finite; present.active.indicative.third.singular, skipping
#
# 71 γε [lemma: γε] (particle)
# Sentence already generated for word γε [lemma: γε] (particle), skipping
#
# 72 ἐξ [lemma: ἐκ] (adposition)
# Sentence already generated for word ἐξ [lemma: ἐκ] (adposition), skipping
#
# 73 τις [lemma: τις] (pronoun) | singular.masculine.nominative
# Sentence already generated for word τις [lemma: τις] (pronoun) | singular.masculine.nominative, skipping
#
# 74 οὕτω [lemma: οὕτω(ς)] (adverb)
# Sentence already generated for word οὕτω [lemma: οὕτω(ς)] (adverb), skipping
#
# 75 αὐτὸν [lemma: αὐτός] (pronoun) | singular.masculine.accusative
# Sentence already generated for word αὐτὸν [lemma: αὐτός] (pronoun) | singular.masculine.accusative, skipping
#
# 76 τοῦ [lemma: ὁ] (determiner) | singular.neuter.genitive
# Sentence already generated for word τοῦ [lemma: ὁ] (determiner) | singular.neuter.genitive, skipping
#
# 77 δέ [lemma: δέ] (particle)
# Sentence already generated for word δέ [lemma: δέ] (particle), skipping
#
# 78 ἂν [lemma: ἄν] (particle)
# Sentence already generated for word ἂν [lemma: ἄν] (particle), skipping
#
# 79 ταῖς [lemma: ὁ] (determiner) | plural.feminine.dative
# Sentence already generated for word ταῖς [lemma: ὁ] (determiner) | plural.feminine.dative, skipping
#
# 80 δʼ [lemma: δʼ] (adjective) | dual.feminine.nominative
# Sentence already generated for word δʼ [lemma: δʼ] (adjective) | dual.feminine.nominative, skipping
#
# 81 μὴ [lemma: μή] (coordinating_conjunction)
# Sentence already generated for word μὴ [lemma: μή] (coordinating_conjunction), skipping
#
# 82 δʼ [lemma: δʼ] (adjective) | singular.neuter.accusative
# Sentence already generated for word δʼ [lemma: δʼ] (adjective) | singular.neuter.accusative, skipping
#
# 83 ἤδη [lemma: ἤδη] (adverb)
# Sentence already generated for word ἤδη [lemma: ἤδη] (adverb), skipping
#
# 84 τοῦτο [lemma: οὗτος] (pronoun) | singular.neuter.accusative
# Sentence already generated for word τοῦτο [lemma: οὗτος] (pronoun) | singular.neuter.accusative, skipping
#
# 85 οὖν [lemma: οὖν] (particle)
# Sentence already generated for word οὖν [lemma: οὖν] (particle), skipping
#
# 86 ἐπεὶ [lemma: ἐπεί] (coordinating_conjunction)
# Sentence already generated for word ἐπεὶ [lemma: ἐπεί] (coordinating_conjunction), skipping
#
# 87 μᾶλλον [lemma: μᾶλλον] (adverb)
# Sentence already generated for word μᾶλλον [lemma: μᾶλλον] (adverb), skipping
#
# 88 τότε [lemma: τότε] (adverb)
# Sentence already generated for word τότε [lemma: τότε] (adverb), skipping
#
# 89 ἐγὼ [lemma: ἐγώ] (pronoun) | singular.masculine.nominative
# Sentence already generated for word ἐγὼ [lemma: ἐγώ] (pronoun) | singular.masculine.nominative, skipping
#
# 90 οὕτως [lemma: οὕτω(ς)] (adverb)
# Sentence already generated for word οὕτως [lemma: οὕτω(ς)] (adverb), skipping
#
# 91 αὐτὸς [lemma: αὐτός] (adjective) | singular.masculine.nominative
# Sentence already generated for word αὐτὸς [lemma: αὐτός] (adjective) | singular.masculine.nominative, skipping
#
# 92 ὥσπερ [lemma: ὥσπερ] (adverb)
# Sentence already generated for word ὥσπερ [lemma: ὥσπερ] (adverb), skipping
#
# 93 οὔτε [lemma: οὔτε] (coordinating_conjunction)
# Sentence already generated for word οὔτε [lemma: οὔτε] (coordinating_conjunction), skipping
#
# 94 πόλιν [lemma: πόλις] (noun) | singular.feminine.accusative
# Sentence already generated for word πόλιν [lemma: πόλις] (noun) | singular.feminine.accusative, skipping
#
# 95 ὧν [lemma: ὅς] (pronoun) | plural.neuter.genitive
# Sentence already generated for word ὧν [lemma: ὅς] (pronoun) | plural.neuter.genitive, skipping
#
# 96 ἀλλʼ [lemma: ἀλλʼ] (verb) | finite; present.active.indicative.second.singular
# Sentence already generated for word ἀλλʼ [lemma: ἀλλʼ] (verb) | finite; present.active.indicative.second.singular, skipping
#
# 97 αἱ [lemma: ὁ] (determiner) | plural.feminine.nominative
# Sentence already generated for word αἱ [lemma: ὁ] (determiner) | plural.feminine.nominative, skipping
#
# 98 σὺν [lemma: σύν] (adposition)
# Sentence already generated for word σὺν [lemma: σύν] (adposition), skipping
#
# 99 γε [lemma: γε] (adverb)
# Sentence already generated for word γε [lemma: γε] (adverb), skipping
#
# 100 αὐτοὺς [lemma: αὐτός] (pronoun) | plural.masculine.accusative
# φονεῦσαι δὲ αὐτοὺς αἰτίη ἔχει Ἀλκμεωνίδας.
# Could not translate sentence 9420; Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. Please check the `candidate.safety_ratings` to determine if the response was blocked.
#
# 101 ὑπὲρ [lemma: ὑπέρ] (adposition)
# Sentence already generated for word ὑπὲρ [lemma: ὑπέρ] (adposition), skipping
#
# 102 μάλιστα [lemma: μάλιστα] (adverb)
# Sentence already generated for word μάλιστα [lemma: μάλιστα] (adverb), skipping
#
# 103 οὐδὲ [lemma: οὐδέ] (coordinating_conjunction)
# Sentence already generated for word οὐδὲ [lemma: οὐδέ] (coordinating_conjunction), skipping
#
# 104 δʼ [lemma: δʼ] (adjective) | singular.masculine.accusative
# Sentence already generated for word δʼ [lemma: δʼ] (adjective) | singular.masculine.accusative, skipping
#
# 105 ἡμῖν [lemma: ἐγώ] (pronoun) | plural.masculine.dative
# εἰσὶ γὰρ ἡμῖν ἀεί που δημιουργοί·
# {'lause': 'On ju meile alati kuskil loojad.', 'märksõna': 'meile [lemma: mina]', 'tõlked': [{'grc': 'εἰσὶ', 'ee': 'on'}, {'grc': 'γὰρ', 'ee': 'ju'}, {'grc': 'ἡμῖν', 'ee': 'meile'}, {'grc': 'ἀεί', 'ee': 'alati'}, {'grc': 'που', 'ee': 'kuskil'}, {'grc': 'δημιουργοί', 'ee': 'loojad'}]}
#
# 106 τῶν [lemma: ὁ] (determiner) | plural.feminine.genitive
# ἡ δὲ φανερωτάτη τῶν αἰτιῶν ἦν ἀρρωστία σώματος·
# {'lause': 'Aga ilmneim nendest (f. gen. pl.) [lemma: see] põhjustest oli keha haigus.', 'märksõna': 'nendest (f. gen. pl.) [lemma: see]', 'tõlked': [{'grc': 'ἡ', 'ee': 'aga'}, {'grc': 'δὲ', 'ee': '[sõna otseses mõttes puudub eesti keeles vaste, rõhutab järgnevat lauset või fraasi]'}, {'grc': 'φανερωτάτη', 'ee': 'ilmneim'}, {'grc': 'τῶν αἰτιῶν', 'ee': 'nendest põhjustest'}, {'grc': 'ἦν', 'ee': 'oli'}, {'grc': 'ἀρρωστία', 'ee': 'haigus'}, {'grc': 'σώματος', 'ee': 'keha'}]}
#
# 107 ἵνα [lemma: ἵνα] (subordinating_conjunction)
# ἀναιρεῖ τὸ πρῶτον ἵνα τὸ δεύτερον στήσῃ.
# {'lause': '[Ta] võtab ära esimese, et teise püstitada.', 'märksõna': 'et [lemma: et]', 'tõlked': [{'grc': 'ἀναιρεῖ', 'ee': '[Ta] võtab ära'}, {'grc': 'τὸ πρῶτον', 'ee': 'esimese'}, {'grc': 'ἵνα', 'ee': 'et'}, {'grc': 'τὸ δεύτερον', 'ee': 'teise'}, {'grc': 'στήσῃ', 'ee': 'püstitada'}]}
#
# 108 τῷ [lemma: ὁ] (determiner) | singular.neuter.dative
# τῷ κυβερνήτῃ ἔγωγε.
# {'lause': 'Roolimehele mina [olen].', 'märksõna': 'roolimehele (m. sg. dat.) [lemma: roolimees]', 'tõlked': [{'grc': 'τῷ', 'ee': 'roolimehele'}, {'grc': 'κυβερνήτῃ', 'ee': ''}, {'grc': 'ἔγωγε', 'ee': 'mina [olen]'}]}
#
# 109 γάρ [lemma: γάρ] (particle)
# τόθι γάρ μιν ἑοῖς ὑπέδεκτο δόμοισιν.
# {'lause': 'Sest seal teda oma kodades ta vastu võttis.', 'märksõna': 'sest [lemma: sest]', 'tõlked': [{'grc': 'τόθι', 'ee': 'seal'}, {'grc': 'γάρ', 'ee': 'sest'}, {'grc': 'μιν', 'ee': 'teda'}, {'grc': 'ἑοῖς δόμοισιν', 'ee': 'oma kodades'}, {'grc': 'ὑπέδεκτο', 'ee': 'vastu võttis'}]}
#
# 110 οὐχ [lemma: οὐ] (adverb)
# οὐχ ἡ δικαστική ;
# {'lause': 'Mitte kohtumõistmis-[kunst]', 'märksõna': 'mitte [lemma: mitte]', 'tõlked': [{'grc': 'οὐχ', 'ee': 'mitte'}, {'grc': 'ἡ δικαστική', 'ee': 'kohtumõistmis-[kunst]'}]}
#
# 111 εἴ [lemma: εἰ] (subordinating_conjunction)
# νυνὶ δὲ χρῆναι λέγειν εἴ τι βούλονται·
# {'lause': 'Nüüd aga [tuleb] öelda, kas nad midagi tahavad.', 'märksõna': 'kas [lemma: kas]', 'tõlked': [{'grc': 'νυνὶ', 'ee': 'nüüd'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'χρῆναι', 'ee': '[tuleb]'}, {'grc': 'λέγειν', 'ee': 'öelda'}, {'grc': 'εἴ', 'ee': 'kas'}, {'grc': 'τι', 'ee': 'midagi'}, {'grc': 'βούλονται', 'ee': 'tahavad'}]}
#
# 112 δέ [lemma: δέ] (adverb)
# ὦκα δέ τοίγε φιτροὺς ἀζαλέης στόρεσαν καθύπερθεν ἐλαίης.
# {'lause': 'Kiiresti aga nad laotasid looduslikud oksad (φιτροὺς) õitsemata oliivipuu (ἐλαίης) peale.', 'märksõna': 'aga [lemma: aga]', 'tõlked': [{'grc': 'ὦκα', 'ee': 'kiiresti'}, {'grc': 'δέ', 'ee': 'aga'}, {'grc': 'τοίγε', 'ee': 'nad'}, {'grc': 'φιτροὺς', 'ee': 'looduslikud oksad'}, {'grc': 'ἀζαλέης', 'ee': 'õitsemata'}, {'grc': 'στόρεσαν', 'ee': 'laotasid'}, {'grc': 'καθύπερθεν', 'ee': 'peale'}, {'grc': 'ἐλαίης', 'ee': 'oliivipuu'}]}
#
# 113 πῶς [lemma: πῶς] (adverb)
# πῶς τῆμος βώσεσθε δυσάμμοροι ;
# Could not translate sentence 1302; Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. Please check the `candidate.safety_ratings` to determine if the response was blocked.
#
# 114 καί [lemma: καί] (coordinating_conjunction)
# καί μοι ὡμολόγει τὰ μέτρια.
# {'lause': 'Ja ta tunnistas mulle parasjagu [mõõdukust] (τὰ μέτρια).', 'märksõna': 'ja [lemma: ja]', 'tõlked': [{'grc': 'καί', 'ee': 'ja'}, {'grc': 'μοι', 'ee': 'mulle'}, {'grc': 'ὡμολόγει', 'ee': 'tunnistas'}, {'grc': 'τὰ μέτρια', 'ee': 'parasjagu'}]}
#
# 115 με [lemma: ἐγώ] (pronoun) | singular.masculine.accusative
# ἀλλὰ τί μύθους Αἰθαλίδεω χρειώ με διηνεκέως ἀγορεύειν ;
# {'lause': 'Aga mida jutustusi Aithalidese [oma] mul [on vaja] alati rääkida?', 'märksõna': 'mul [lemma: mina]', 'tõlked': [{'grc': 'ἀλλὰ', 'ee': 'aga'}, {'grc': 'τί', 'ee': 'mida'}, {'grc': 'μύθους', 'ee': 'jutustusi'}, {'grc': 'Αἰθαλίδεω', 'ee': 'Aithalidese'}, {'grc': 'χρειώ ...  ἀγορεύειν', 'ee': '[on vaja] ... rääkida'}, {'grc': 'με', 'ee': 'mul'}, {'grc': 'διηνεκέως', 'ee': 'alati'}]}
#
# 116 τὰ [lemma: ὁ] (determiner) | plural.neuter.nominative
# τὰ μέτρια ἢ τὰ πολλά ;
# {'lause': 'Mõõdukad [asjad] või paljud [asjad]?', 'märksõna': 'need (n. nom. pl.) [lemma: see]', 'tõlked': [{'grc': 'τὰ', 'ee': 'need'}, {'grc': 'μέτρια', 'ee': 'mõõdukad'}, {'grc': 'ἢ', 'ee': 'või'}, {'grc': 'τὰ', 'ee': 'need'}, {'grc': 'πολλά', 'ee': 'paljud'}]}
#
# 117 οἱ [lemma: ἕ] (pronoun) | singular.masculine.dative
# οἱ δʼἐπανέσταν πειθόμενοι·
# {'lause': 'Need [aga] tõusid üles, olles veendunud.', 'märksõna': 'need (m. dat. sg.) [lemma: see]', 'tõlked': [{'grc': 'οἱ', 'ee': 'need'}, {'grc': 'δʼἐπανέσταν', 'ee': 'tõusid üles'}, {'grc': 'πειθόμενοι', 'ee': 'olles veendunud'}]}
#
# 118 δὴ [lemma: δή] (particle)
# δὴ τότʼ ἀνέγρετο Τῖφυς·
# {'lause': 'Siis ärkas [üles] Tüfüs.', 'märksõna': 'siis [lemma: siis]', 'tõlked': [{'grc': 'δὴ', 'ee': 'siis'}, {'grc': 'τότʼ', 'ee': ''}, {'grc': 'ἀνέγρετο', 'ee': 'ärkas [üles]'}, {'grc': 'Τῖφυς', 'ee': 'Tüfüs'}]}
#
# 119 ἐστι [lemma: εἰμί] (auxiliary) | finite; present.active.indicative.third.singular
# οὐδὲν γάρ ἐστι —
# {'lause': 'Sest pole midagi —', 'märksõna': 'on [lemma: olema]', 'tõlked': [{'grc': 'οὐδὲν', 'ee': 'midagi'}, {'grc': 'γάρ', 'ee': 'sest'}, {'grc': 'ἐστι', 'ee': 'on'}, {'grc': '—', 'ee': '—'}]}
#
# 120 γενέσθαι [lemma: γίγνομαι] (verb) | infinitive; past.middle
# οἶδα ἐγὼ οὕτω ἀκούσας γενέσθαι :
# {'lause': 'Mina tean nõnda kuulnud olevat juhtunud.', 'märksõna': 'juhtunud [lemma: juhtuma]', 'tõlked': [{'grc': 'οἶδα', 'ee': 'tean'}, {'grc': 'ἐγὼ', 'ee': 'mina'}, {'grc': 'οὕτω', 'ee': 'nõnda'}, {'grc': 'ἀκούσας', 'ee': 'kuulnud'}, {'grc': 'γενέσθαι', 'ee': 'olevat juhtunud'}]}
#
# 121 εἴη [lemma: εἰμί] (auxiliary) | finite; present.active.optative.third.singular
# δὴ γάρ κεν ἀφαυροτέρη χάρις εἴη.
# {'lause': 'Sest tõesti [see] oleks tühisem au.', 'märksõna': 'oleks [lemma: olema]', 'tõlked': [{'grc': 'δὴ', 'ee': 'tõesti'}, {'grc': 'γάρ', 'ee': 'sest'}, {'grc': 'κεν', 'ee': '[see]'}, {'grc': 'ἀφαυροτέρη', 'ee': 'tühisem'}, {'grc': 'χάρις', 'ee': 'au'}, {'grc': 'εἴη', 'ee': 'oleks'}]}
#
# 122 πάντα [lemma: πᾶς] (adjective) | plural.neuter.accusative
# τὰ δὲ πάντα Διὸς βουλῇς ἐτέτυκτο.
# {'lause': 'Kõik aga oli Zeusi tahtel loodud (ἐτέτυκτο).', 'märksõna': 'kõik [lemma: kõik]', 'tõlked': [{'grc': 'τὰ', 'ee': 'kõik'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'πάντα', 'ee': 'kõik'}, {'grc': 'Διὸς', 'ee': 'Zeusi'}, {'grc': 'βουλῇς', 'ee': 'tahtel'}, {'grc': 'ἐτέτυκτο', 'ee': 'loodud'}]}
#
# 123 ἔστι [lemma: εἰμί] (auxiliary) | finite; present.active.indicative.third.singular
# ἔστι δὲ καὶ τοῦτο Διός
# {'lause': 'Ja see on ka Zeusi [oma].', 'märksõna': 'on [lemma: olema]', 'tõlked': [{'grc': 'ἔστι', 'ee': 'on'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'καὶ', 'ee': 'ka'}, {'grc': 'τοῦτο', 'ee': 'see'}, {'grc': 'Διός', 'ee': 'Zeusi'}]}
#
# 124 ὃς [lemma: ὅς] (pronoun) | singular.masculine.nominative
# οὗτος εἴη ὃς τὴν ψυχὴν ἀπέδωκε.
# {'lause': 'See oleks too, kes hinge andis (ära andis).', 'märksõna': 'kes [lemma: kes]', 'tõlked': [{'grc': 'οὗτος', 'ee': 'see'}, {'grc': 'εἴη', 'ee': 'oleks'}, {'grc': 'ὃς', 'ee': 'kes'}, {'grc': 'τὴν ψυχὴν', 'ee': 'hinge'}, {'grc': 'ἀπέδωκε', 'ee': 'andis (ära andis)'}]}
#
# 125 πρῶτον [lemma: πρῶτος] (adjective) | singular.neuter.accusative
# καὶ πρῶτον μὲν ἦν ποιμένων θαῦμα καὶ βοτήρων
# {'lause': 'Ja esiteks oli see karjaste ja karjatüdrukute imeks.', 'märksõna': 'esiteks [lemma: esiteks]', 'tõlked': [{'grc': 'καὶ', 'ee': 'ja'}, {'grc': 'πρῶτον', 'ee': 'esiteks'}, {'grc': 'μὲν', 'ee': ''}, {'grc': 'ἦν', 'ee': 'oli'}, {'grc': 'ποιμένων', 'ee': 'karjaste'}, {'grc': 'θαῦμα', 'ee': 'imeks'}, {'grc': 'καὶ', 'ee': 'ja'}, {'grc': 'βοτήρων', 'ee': 'karjatüdrukute'}]}
#
# 126 οὐδὲν [lemma: οὐδείς] (adjective) | singular.neuter.accusative
# ἀλλʼ οὐδὲν αὐτοῦ δεῖ·
# {'lause': 'Kuid temast [pole] midagi vaja.', 'märksõna': 'midagi [lemma: miski]', 'tõlked': [{'grc': 'ἀλλʼ', 'ee': 'kuid'}, {'grc': 'οὐδὲν', 'ee': 'midagi'}, {'grc': 'αὐτοῦ', 'ee': 'temast'}, {'grc': 'δεῖ', 'ee': 'vaja'}]}
#
# 127 ὥστε [lemma: ὥστε] (subordinating_conjunction)
# αὐτὸν δʼ ὥστε θεὸν Πολυδεύκεα δεξιόωντο πάντοθεν ἀγρόμενοι·
# {'lause': 'Nii et [nagu] jumalat Polydeukest austasid nad, igalt poolt kokku tulles.', 'märksõna': 'nii et [lemma: nii et]', 'tõlked': [{'grc': 'αὐτὸν', 'ee': '[teda]'}, {'grc': 'δʼ', 'ee': '[--]'}, {'grc': 'ὥστε', 'ee': 'nii et'}, {'grc': 'θεὸν', 'ee': 'jumalat'}, {'grc': 'Πολυδεύκεα', 'ee': 'Polydeukest'}, {'grc': 'δεξιόωντο', 'ee': 'austasid'}, {'grc': 'πάντοθεν', 'ee': 'igalt poolt'}, {'grc': 'ἀγρόμενοι', 'ee': 'kokku tulles'}]}
#
# 128 πολλὰ [lemma: πολύς] (adjective) | plural.neuter.accusative
# πολλὰ δʼ ἔτυμα παιδότρωτα πάθεα προσμένει τοκεῦ
# {'lause': 'Palju [on neid] õiglasi lastekaotamise kannatusi, mis ema ees ootavad.', 'märksõna': 'palju [lemma: palju]', 'tõlked': [{'grc': 'πολλὰ', 'ee': 'palju'}, {'grc': 'δʼ ἔτυμα', 'ee': '[on neid] õiglasi'}, {'grc': 'παιδότρωτα', 'ee': 'lastekaotamise'}, {'grc': 'πάθεα', 'ee': 'kannatusi'}, {'grc': 'προσμένει', 'ee': 'ootavad'}, {'grc': 'τοκεῦ', 'ee': 'ema ees'}]}
#
# 129 πολὺ [lemma: πολύς] (adjective) | singular.neuter.accusative
# πολὺ γὰρ πλείω ὠφεληθήσεσθʼ, ἐὰν ἡμεῖς ἔχωμεν.
# {'lause': 'Sest palju enam te saate kasu (ὠφεληθήσεσθʼ), kui meie [seda] omame.', 'märksõna': 'palju [lemma: palju]', 'tõlked': [{'grc': 'πολὺ', 'ee': 'palju'}, {'grc': 'γὰρ', 'ee': 'sest'}, {'grc': 'πλείω', 'ee': 'enam'}, {'grc': 'ὠφεληθήσεσθʼ', 'ee': 'saate kasu'}, {'grc': 'ἐὰν', 'ee': 'kui'}, {'grc': 'ἡμεῖς', 'ee': 'meie'}, {'grc': 'ἔχωμεν', 'ee': 'omame'}]}
#
# 130 τούτων [lemma: οὗτος] (pronoun) | plural.neuter.genitive
# τούτων δὲ κεφάλαιόν τι γίγνεται περὶ τετταράκοντα τάλαντα.
# {'lause': 'Nende [tulude] summa on umbes nelikümmend talenti.', 'märksõna': 'nende (n. gen. pl.) [lemma: see]', 'tõlked': [{'grc': 'τούτων', 'ee': 'nende'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'κεφάλαιόν τι', 'ee': 'summa'}, {'grc': 'γίγνεται', 'ee': 'on'}, {'grc': 'περὶ', 'ee': 'umbes'}, {'grc': 'τετταράκοντα', 'ee': 'nelikümmend'}, {'grc': 'τάλαντα', 'ee': 'talenti'}]}
#
# 131 οὐδʼ [lemma: οὐδʼ] (adverb)
# οὐδʼ ἀπόνητο δωτίνης·
# {'lause': 'Ei [ta] loobunud ka kingitusest.', 'märksõna': 'ka [lemma: ka]', 'tõlked': [{'grc': 'οὐδʼ', 'ee': 'ka'}, {'grc': 'ἀπόνητο', 'ee': 'loobunud'}, {'grc': 'δωτίνης', 'ee': 'kingitusest'}]}
#
# 132 ἃ [lemma: ὅς] (pronoun) | plural.neuter.accusative
# ἃ δὲ κατέλιπεν, ἀναγνώσεται ὑμῖν.
# {'lause': 'Mis ta aga maha jättis, loetakse teile ette.', 'märksõna': 'mis [lemma: mis]', 'tõlked': [{'grc': 'ἃ', 'ee': 'mis'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'κατέλιπεν', 'ee': 'maha jättis'}, {'grc': 'ἀναγνώσεται', 'ee': 'loetackse ette'}, {'grc': 'ὑμῖν', 'ee': 'teile'}]}
#
# 133 ἀλλὰ [lemma: ἀλλά] (adverb)
# ἀλλὰ ταῦτα μὲν ἐπράχθη συχνῷ τινι χρόνῳ πρότερον.
# {'lause': 'Aga need asjad [toimusid] küll [juba] mõnda aega varem.', 'märksõna': 'aga [lemma: aga]', 'tõlked': [{'grc': 'ἀλλὰ', 'ee': 'aga'}, {'grc': 'ταῦτα', 'ee': 'need asjad'}, {'grc': 'μὲν', 'ee': 'küll'}, {'grc': 'ἐπράχθη', 'ee': 'toimusid'}, {'grc': 'συχνῷ τινι χρόνῳ', 'ee': 'mõnda aega'}, {'grc': 'πρότερον', 'ee': 'varem'}]}
#
# 134 ἔχειν [lemma: ἔχω] (verb) | infinitive; present.active
# οὐδʼ ἂν δεχοίμην ὥστʼ ἔχειν τιμὰς σέθεν.
# {'lause': 'Ei ma ka vastu võtaks, nõnda et oleksid minul sinu auavaldused.', 'märksõna': 'oleksid [lemma: olema]', 'tõlked': [{'grc': 'οὐδʼ', 'ee': 'ei [ka]'}, {'grc': 'ἂν', 'ee': '[osake]'}, {'grc': 'δεχοίμην', 'ee': 'vastu võtaks'}, {'grc': 'ὥστʼ', 'ee': 'nõnda et'}, {'grc': 'ἔχειν', 'ee': 'oleksid'}, {'grc': 'τιμὰς', 'ee': 'auavaldused'}, {'grc': 'σέθεν', 'ee': 'sinu'}]}
#
# 135 δοκεῖ [lemma: δοκέω] (verb) | finite; present.active.indicative.third.singular
# τοῖς[ι ] ταύτῃ πῶς δοκεῖ ;
# {'lause': 'Nendele [naistele] kuidas [see] näib?', 'märksõna': 'näib [lemma: näima]', 'tõlked': [{'grc': 'τοῖς[ι ] ταύτῃ', 'ee': 'nendele'}, {'grc': 'πῶς', 'ee': 'kuidas'}, {'grc': 'δοκεῖ', 'ee': 'näib'}]}
#
# 136 εὖ [lemma: εὖ] (adverb)
# --πάντα γὰρ εὖ κατὰ κόσμον--ἐπαρτέα κεῖται ἰοῦσιν.
# {'lause': 'Sest kõik on hästi maailma järgi seatud minejatele.', 'märksõna': 'hästi [lemma: hästi]', 'tõlked': [{'grc': '--πάντα', 'ee': 'kõik'}, {'grc': 'γὰρ', 'ee': 'sest'}, {'grc': 'εὖ', 'ee': 'hästi'}, {'grc': 'κατὰ κόσμον', 'ee': 'maailma järgi'}, {'grc': 'ἐπαρτέα', 'ee': 'seatud'}, {'grc': 'κεῖται', 'ee': 'on'}, {'grc': 'ἰοῦσιν', 'ee': 'minejatele'}]}
#
# 137 μόνον [lemma: μόνος] (adjective) | singular.neuter.accusative
# μόνον τόδʼ Ἑλλὰς χθὼν συνοίσεται στόχῳ.
# {'lause': 'Ainult seda [kavatseb] Hellase maa viia eesmärgini.', 'märksõna': 'ainult [lemma: ainult]', 'tõlked': [{'grc': 'μόνον', 'ee': 'ainult'}, {'grc': 'τόδʼ', 'ee': 'seda'}, {'grc': 'Ἑλλὰς χθὼν', 'ee': 'Hellase maa'}, {'grc': 'συνοίσεται', 'ee': 'viia'}, {'grc': 'στόχῳ', 'ee': 'eesmärgini'}]}
#
# 138 αὖ [lemma: αὖ] (adverb)
# Ναύβολος αὖ Λέρνου·
# {'lause': 'Naubolos aga Lernolt.', 'märksõna': 'aga [lemma: aga]', 'tõlked': [{'grc': 'Ναύβολος', 'ee': 'Naubolos'}, {'grc': 'αὖ', 'ee': 'aga'}, {'grc': 'Λέρνου', 'ee': 'Lernolt'}]}
#
# 139 ἔχει [lemma: ἔχω] (verb) | finite; present.active.indicative.third.singular
# τίπτε με δειλαίην τόδʼ ἔχει ἄχος ;
# {'lause': 'Miks ometi [see] mind viletsat kurvastus hoiab?', 'märksõna': 'hoiab [lemma: hoidma]', 'tõlked': [{'grc': 'τίπτε', 'ee': 'miks ometi'}, {'grc': 'με', 'ee': 'mind'}, {'grc': 'δειλαίην', 'ee': 'viletsat'}, {'grc': 'τόδʼ', 'ee': '[see]'}, {'grc': 'ἔχει', 'ee': 'hoiab'}, {'grc': 'ἄχος', 'ee': 'kurvastus'}]}
#
# 140 ἄλλων [lemma: ἄλλος] (adjective) | plural.masculine.genitive
# παρῆν δὲ καὶ τῶν ἄλλων Παλληναίων συμμαχίν.
# {'lause': 'Oli kohal aga ka teiste  Pallenelaste liitlasi.', 'märksõna': 'teiste (m. gen. pl.) [lemma: teine]', 'tõlked': [{'grc': 'παρῆν', 'ee': 'oli kohal'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'καὶ', 'ee': 'ka'}, {'grc': 'τῶν ἄλλων', 'ee': 'teiste'}, {'grc': 'Παλληναίων', 'ee': 'Pallenelaste'}, {'grc': 'συμμαχίν', 'ee': 'liitlasi'}]}
#
# 141 αὐτὸν [lemma: αὐτός] (adjective) | singular.masculine.accusative
# ἐν δὲ καὶ αὐτὸν ἱστὸν ἄφαρ χαλάσαντο παρακλιδόν·
# {'lause': 'Ja kohe ka [purje] ise lasid nad alla kaldus.', 'märksõna': 'ise [lemma: ise]', 'tõlked': [{'grc': 'ἐν', 'ee': '[siis]'}, {'grc': 'δὲ', 'ee': 'ja'}, {'grc': 'καὶ', 'ee': 'ka'}, {'grc': 'αὐτὸν', 'ee': 'ise'}, {'grc': 'ἱστὸν', 'ee': '[purje]'}, {'grc': 'ἄφαρ', 'ee': 'kohe'}, {'grc': 'χαλάσαντο', 'ee': 'lasid [nad] alla'}, {'grc': 'παρακλιδόν', 'ee': 'kaldus'}]}
#
# 142 ἦσαν [lemma: εἰμί] (auxiliary) | finite; past.active.indicative.third.plural
# αὗται μὲν ἀρχαί τε ἦσαν καὶ φόρων ἐπιτάξιες.
# {'lause': 'Need [siis] olid nii vanad kui ka maksude kehtestamised.', 'märksõna': 'olid [lemma: olema]', 'tõlked': [{'grc': 'αὗται', 'ee': 'need'}, {'grc': 'μὲν', 'ee': '[siis]'}, {'grc': 'ἀρχαί τε ἦσαν', 'ee': 'olid nii vanad'}, {'grc': 'καὶ', 'ee': 'kui ka'}, {'grc': 'φόρων ἐπιτάξιες', 'ee': 'maksude kehtestamised'}]}
#
# 143 ὅπως [lemma: ὅπως] (subordinating_conjunction)
# αὐτὰρ ἑταῖροι γηθόσυνοι ἐρέεινον, ὅπως παρεόντας ἴδοντο·
# {'lause': 'Aga kaaslased küsisid rõõmuga, kuidas (ὅπως) nad neid kohal nägid.', 'märksõna': 'kuidas [lemma: kuidas]', 'tõlked': [{'grc': 'αὐτὰρ', 'ee': 'aga'}, {'grc': 'ἑταῖροι', 'ee': 'kaaslased'}, {'grc': 'γηθόσυνοι', 'ee': 'rõõmuga'}, {'grc': 'ἐρέεινον', 'ee': 'küsisid'}, {'grc': 'ὅπως', 'ee': 'kuidas'}, {'grc': 'παρεόντας ἴδοντο', 'ee': 'nägid [neid] kohal'}]}
#
# 144 λέγειν [lemma: λέγω] (verb) | infinitive; present.active
# ἔξεστι γάρ μοι μὴ λέγειν ἃ μὴ τελῶ.
# {'lause': 'Sest mul on lubatud mitte öelda seda (ἃ), mida ma ei tee.', 'märksõna': 'öelda [lemma: öelda]', 'tõlked': [{'grc': 'ἔξεστι', 'ee': 'on lubatud'}, {'grc': 'γάρ', 'ee': 'sest'}, {'grc': 'μοι', 'ee': 'mul'}, {'grc': 'μὴ', 'ee': 'mitte'}, {'grc': 'λέγειν', 'ee': 'öelda'}, {'grc': 'ἃ', 'ee': 'seda'}, {'grc': 'μὴ', 'ee': 'mida'}, {'grc': 'τελῶ', 'ee': 'tee'}]}
#
# 145 τοῦτο [lemma: οὗτος] (adjective) | singular.neuter.accusative
# αὔτʼ ἐστι τοῦτο μέτρον [ ἐ]κμε [ τρού]μ[ε]νον.
# {'lause': 'See on see mõõt, välja mõõdetud.', 'märksõna': 'see [lemma: see]', 'tõlked': [{'grc': 'αὔτʼ', 'ee': 'see'}, {'grc': 'ἐστι', 'ee': 'on'}, {'grc': 'τοῦτο', 'ee': 'see'}, {'grc': 'μέτρον', 'ee': 'mõõt'}, {'grc': 'ἐ]κμε[τρού]μ[ε]νον', 'ee': 'välja mõõdetud'}]}
#
# 146 ἔστιν [lemma: εἰμί] (auxiliary) | finite; present.active.indicative.third.singular
# θέμις δʼ οὐκ ἔστιν ἁλῶναι.
# {'lause': 'Seadus [aga] ei ole püütuks saada.', 'märksõna': 'on [lemma: olema]', 'tõlked': [{'grc': 'θέμις', 'ee': 'seadus'}, {'grc': 'δʼ', 'ee': '[aga]'}, {'grc': 'οὐκ', 'ee': 'ei'}, {'grc': 'ἔστιν', 'ee': 'on'}, {'grc': 'ἁλῶναι', 'ee': 'püütuks saada'}]}
#
# 147 ἔχων [lemma: ἔχω] (verb) | participle; present.active.singular.nominative
# τί ποτε βακχεύεις ἔχων ;
# {'lause': 'Miks sa [ometi] oled bakhhent, omades?', 'märksõna': 'omades [lemma: omama]', 'tõlked': [{'grc': 'τί', 'ee': 'miks'}, {'grc': 'ποτε', 'ee': '[ometi]'}, {'grc': 'βακχεύεις', 'ee': 'oled bakhhent'}, {'grc': 'ἔχων', 'ee': 'omades'}]}
#
# 148 οὗτος [lemma: οὗτος] (adjective) | singular.masculine.nominative
# οὗτος ὑπέστη τόν ἆθλον ἑκούσιος.
# {'lause': 'See [mees] võttis selle a[t]hlo[o]se (ἆθλον) vabatahtlikult vastu.', 'märksõna': 'See [m. sg. nom.] [lemma: see]', 'tõlked': [{'grc': 'οὗτος', 'ee': 'See'}, {'grc': 'ὑπέστη', 'ee': 'võttis vastu'}, {'grc': 'τόν ἆθλον', 'ee': 'athloo'}, {'grc': 'ἑκούσιος', 'ee': 'vabatahtlikult'}]}
#
# 149 αὐτῷ [lemma: αὐτός] (adjective) | singular.masculine.dative
# αὐτῷ γὰρ ἑκὼν ἐρίδηνε δοτῆρι.
# {'lause': 'Sest ta ise [olid] kingiandjaga tülli läinud.', 'märksõna': 'talle [lemma: tema]', 'tõlked': [{'grc': 'αὐτῷ', 'ee': 'talle'}, {'grc': 'γὰρ', 'ee': 'sest'}, {'grc': 'ἑκὼν', 'ee': 'ise'}, {'grc': 'ἐρίδηνε', 'ee': '[olid] tülli läinud'}, {'grc': 'δοτῆρι', 'ee': 'kingiandjaga'}]}
#
# 150 πάνυ [lemma: πάνυ] (adverb)
# κἀκεῖνος, πάνυ, ἔφη.
# {'lause': 'Ja tema, väga, ütles.', 'märksõna': 'väga [lemma: väga]', 'tõlked': [{'grc': 'κἀκεῖνος', 'ee': 'ja tema'}, {'grc': 'πάνυ', 'ee': 'väga'}, {'grc': 'ἔφη', 'ee': 'ütles'}]}
#
# 151 δεῖ [lemma: δεῖ] (verb) | finite; present.active.indicative.third.singular
# δεῖ γὰρ πλεῦνας γενομένους οὕτω ἐπιχειρέειν.
# {'lause': 'Sest tuleb, kui neid on rohkem [saanud], nõnda katsetada.', 'märksõna': 'tuleb [lemma: tulema]', 'tõlked': [{'grc': 'δεῖ', 'ee': 'tuleb'}, {'grc': 'γὰρ', 'ee': 'sest'}, {'grc': 'πλεῦνας', 'ee': 'rohkem'}, {'grc': 'γενομένους', 'ee': '[saanud]'}, {'grc': 'οὕτω', 'ee': 'nõnda'}, {'grc': 'ἐπιχειρέειν', 'ee': 'katsetada'}]}
#
# 152 πρότερον [lemma: πρότερος] (adjective) | singular.neuter.accusative
# δίειμι δὲ τὸν μυθώδη πρότερον.
# {'lause': 'Ja ma räägin (jutustan) [selle] müüdi enne.', 'märksõna': 'enne [lemma: enne]', 'tõlked': [{'grc': 'δίειμι', 'ee': 'räägin'}, {'grc': 'δὲ', 'ee': 'ja'}, {'grc': 'τὸν μυθώδη', 'ee': '[selle] müüdi'}, {'grc': 'πρότερον', 'ee': 'enne'}]}
#
# 153 παρʼ [lemma: παρʼ] (verb) | finite; present.active.indicative.first.singular
# ἐγὼ δὲ παρʼ Ἀντικλέους εἰρήνης οὔσης ὠνοῦμαι.
# {'lause': 'Mina aga ostsin selle Antiklese (rahu) ajal.', 'märksõna': 'ostsin [lemma: ostma]', 'tõlked': [{'grc': 'ἐγὼ', 'ee': 'Mina'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'παρʼ', 'ee': 'ostsin'}, {'grc': 'Ἀντικλέους', 'ee': 'Antiklese'}, {'grc': 'εἰρήνης', 'ee': '(rahu)'}, {'grc': 'οὔσης', 'ee': 'ajal'}, {'grc': 'ὠνοῦμαι', 'ee': 'selle'}]}
#
# 154 ἐστὶν [lemma: εἰμί] (auxiliary) | finite; present.active.indicative.third.singular
# ἀλλʼ ὡς κεράστ[η]ς κάνθαρος δῆτʼ ἐστὶν Αἰτναῖος φυήν ;
# {'lause': 'Aga nagu sarvedega mardikas tõesti on Etna [vulkaani] loomult.', 'märksõna': 'on [lemma: olema]', 'tõlked': [{'grc': 'ἀλλʼ', 'ee': 'aga'}, {'grc': 'ὡς', 'ee': 'nagu'}, {'grc': 'κεράστ[η]ς κάνθαρος', 'ee': 'sarvedega mardikas'}, {'grc': 'δῆτʼ', 'ee': 'tõesti'}, {'grc': 'ἐστὶν', 'ee': 'on'}, {'grc': 'Αἰτναῖος', 'ee': 'Etna [vulkaani]'}, {'grc': 'φυήν', 'ee': 'loomult'}]}
#
# 155 πάλιν [lemma: πάλιν] (adverb)
# αἱροῦνται δὴ πάλιν χιλίαρχον τὸν Κάμιλλον.
# {'lause': 'Valivad siis jälle [endaks] tuhandepealikuks Camilluse.', 'märksõna': 'jälle [lemma: jälle]', 'tõlked': [{'grc': 'αἱροῦνται', 'ee': 'valivad'}, {'grc': 'δὴ', 'ee': 'siis'}, {'grc': 'πάλιν', 'ee': 'jälle'}, {'grc': 'χιλίαρχον', 'ee': 'tuhandepealikuks'}, {'grc': 'τὸν Κάμιλλον', 'ee': 'Camilluse'}]}
#
# 156 δύο [lemma: δύο] (numeral) | None.None.None
# καὶ δʼ ἄλλω δύο παῖδε Ποσειδάωνοςἵκοντο·
# {'lause': 'Ja kaks teist [Posideoni] poega saabusid.', 'märksõna': 'kaks [lemma: kaks]', 'tõlked': [{'grc': 'καὶ', 'ee': 'ja'}, {'grc': 'δʼ', 'ee': '[konteksti puudumisel tõlkendamatu partikkel]'}, {'grc': 'ἄλλω', 'ee': '[konteksti puudumisel tõlkendamatu verb]'}, {'grc': 'δύο', 'ee': 'kaks'}, {'grc': 'παῖδε', 'ee': 'poega'}, {'grc': 'Ποσειδάωνοςἵκοντο', 'ee': '[Posideoni] saabusid'}]}
#
# 157 ἢ [lemma: ἤ] (adverb)
# πλὴν ἢ τὰ λεγόμενα.
# {'lause': 'Välja arvatud [need], mida räägitakse.', 'märksõna': 'või [lemma: või]', 'tõlked': [{'grc': 'πλὴν', 'ee': 'välja arvatud'}, {'grc': 'ἢ', 'ee': 'või'}, {'grc': 'τὰ λεγόμενα', 'ee': '[need], mida räägitakse'}]}
#
# 158 θεῶν [lemma: θεός] (noun) | plural.masculine.genitive
# φέρε πρὸς θεῶν Ὀλυμπίων·
# {'lause': 'Ütle ometi Olümpose jumalate nimel!', 'märksõna': 'jumalate (m. gen. pl.) [lemma: jumal]', 'tõlked': [{'grc': 'φέρε', 'ee': 'Ütle'}, {'grc': 'πρὸς θεῶν Ὀλυμπίων', 'ee': 'Olümpose jumalate nimel'}, {'grc': '·', 'ee': '!'}]}
#
# 159 ἐμοὶ [lemma: ἐγώ] (pronoun) | singular.masculine.dative
# μήτις ἐμοὶ τόδε κῦδος ὀπαζέτω.
# {'lause': 'Mitte keegi [ärgu] mulle seda au järgnegu.', 'märksõna': 'mulle [lemma: mina]', 'tõlked': [{'grc': 'μήτις', 'ee': 'mitte keegi'}, {'grc': 'ἐμοὶ', 'ee': 'mulle'}, {'grc': 'τόδε', 'ee': 'seda'}, {'grc': 'κῦδος', 'ee': 'au'}, {'grc': 'ὀπαζέτω', 'ee': 'järgnegu'}]}
#
# 160 τοῖς [lemma: ὁ] (determiner) | plural.neuter.dative
# τοῖς ἴκελοι ἥρωες ὑπὲξ ἁλὸς εἷλκον ἐρετμά.
# {'lause': 'Nendega (m. pl.) [lemma: need] sarnased kangelased vedasid mere [alt] aerud [välja].', 'märksõna': 'nendega (m. pl.) [lemma: need]', 'tõlked': [{'grc': 'τοῖς', 'ee': 'nendega'}, {'grc': 'ἴκελοι', 'ee': 'sarnased'}, {'grc': 'ἥρωες', 'ee': 'kangelased'}, {'grc': 'ὑπὲξ ἁλὸς', 'ee': 'mere [alt]'}, {'grc': 'εἷλκον', 'ee': 'vedasid'}, {'grc': 'ἐρετμά', 'ee': 'aerud [välja]'}]}
#
# 161 πάντων [lemma: πᾶς] (adjective) | plural.masculine.genitive
# ἀναρμοστότατον δὲ πάντων :
# {'lause': 'Kõige sobimatum aga kõigist :', 'märksõna': 'kõigist (m. gen. pl.) [lemma: kõik]', 'tõlked': [{'grc': 'ἀναρμοστότατον', 'ee': 'kõige sobimatum'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'πάντων', 'ee': 'kõigist'}, {'grc': ':', 'ee': ':'}]}
#
# 162 οἳ [lemma: ὁ] (pronoun) | plural.masculine.nominative
# οἳ δὲ διζήμενοι μίσγεσθαι αὐτῇσι οὐκ ἔχουσι.
# {'lause': 'Kes aga, otsides nendega ühineda, ei saa [seda teha].', 'märksõna': 'kes [lemma: kes]', 'tõlked': [{'grc': 'οἳ', 'ee': 'kes'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'διζήμενοι', 'ee': 'otsides'}, {'grc': 'μίσγεσθαι', 'ee': 'ühineda'}, {'grc': 'αὐτῇσι', 'ee': 'nendega'}, {'grc': 'οὐκ', 'ee': 'ei'}, {'grc': 'ἔχουσι', 'ee': 'saa [seda teha]'}]}
#
# 163 οὔτε [lemma: οὔτε] (adverb)
# οὔτε γὰρ ἡδὺ οὔτε ἀγαθόν.
# {'lause': 'Sest ei ole meeldiv ega hea.', 'märksõna': 'ei ... ega [lemma: ei ... ega]', 'tõlked': [{'grc': 'οὔτε', 'ee': 'ei'}, {'grc': 'γὰρ', 'ee': 'sest'}, {'grc': 'ἡδὺ', 'ee': 'meeldiv'}, {'grc': 'οὔτε', 'ee': 'ega'}, {'grc': 'ἀγαθόν', 'ee': 'hea'}]}
#
# 164 ταῦτα [lemma: οὗτος] (adjective) | plural.neuter.accusative
# μή μοι ταῦτα νόῳ ἔνι βάλλεο, τέκνον.
# {'lause': 'Ära [neid] mulle südamesse pane, mu laps!', 'märksõna': '[neid] (n. pl. acc.) [lemma: see]', 'tõlked': [{'grc': 'μή', 'ee': 'ära'}, {'grc': 'μοι', 'ee': 'mulle'}, {'grc': 'ταῦτα', 'ee': '[neid]'}, {'grc': 'νόῳ ἔνι', 'ee': 'südamesse'}, {'grc': 'βάλλεο', 'ee': 'pane'}, {'grc': 'τέκνον', 'ee': 'laps'}]}
#
# 165 θεοῦ [lemma: θεός] (noun) | singular.masculine.genitive
# δὴ γὰρ θεοῦ ἐτράπεθʼ ὁρμῇ.
# {'lause': 'Sest jumala  hoole alla ta läks.', 'märksõna': 'jumala (m. sg. gen) [lemma: jumal]', 'tõlked': [{'grc': 'δὴ', 'ee': 'sest'}, {'grc': 'γὰρ', 'ee': ''}, {'grc': 'θεοῦ', 'ee': 'jumala'}, {'grc': 'ἐτράπεθʼ', 'ee': 'läks'}, {'grc': 'ὁρμῇ', 'ee': 'hoole alla'}]}
#
# 166 λόγον [lemma: λόγος] (noun) | singular.masculine.accusative
# μάθοιμʼ ἄν, εἰ λέγοι τις ἐμφανῆ λόγον.
# {'lause': 'Ma õpiksin, kui keegi ütleks selge sõnumi (λόγον).', 'märksõna': 'sõnumi [lemma: sõnum]', 'tõlked': [{'grc': 'μάθοιμʼ', 'ee': 'ma õpiksin'}, {'grc': 'ἄν', 'ee': '[kui]'}, {'grc': 'εἰ', 'ee': 'kui'}, {'grc': 'λέγοι', 'ee': 'ütleks'}, {'grc': 'τις', 'ee': 'keegi'}, {'grc': 'ἐμφανῆ', 'ee': 'selge'}, {'grc': 'λόγον', 'ee': 'sõnumi'}]}
#
# 167 δʼ [lemma: δʼ] (adjective) | plural.neuter.nominative
# Μοῦσαι δʼ ὑποφήτορες εἶεν ἀοιδῆς.
# {'lause': 'Muusad aga [olgu] laulu kuulutajad.', 'märksõna': '[olgu] [lemma: olema]', 'tõlked': [{'grc': 'Μοῦσαι', 'ee': 'Muusad'}, {'grc': 'δʼ', 'ee': 'aga'}, {'grc': 'ὑποφήτορες', 'ee': 'kuulutajad'}, {'grc': 'εἶεν', 'ee': '[olgu]'}, {'grc': 'ἀοιδῆς', 'ee': 'laulu'}]}
#
# 168 ἀνθρώπων [lemma: ἄνθρωπος] (noun) | plural.masculine.genitive
# τοῦτο ἐς ἐπίδεξιν ἀνθρώπων ἀπίκετο.
# {'lause': 'See inimeste ette näitamiseks (ἐς ἐπίδεξιν) saabus.', 'märksõna': 'inimeste (m. gen. pl.) [lemma: inimene]', 'tõlked': [{'grc': 'τοῦτο', 'ee': 'see'}, {'grc': 'ἐς ἐπίδεξιν', 'ee': 'ette näitamiseks'}, {'grc': 'ἀνθρώπων', 'ee': 'inimeste'}, {'grc': 'ἀπίκετο', 'ee': 'saabus'}]}
#
# 169 πάντες [lemma: πᾶς] (adjective) | plural.masculine.nominative
# μιῇ δέ ἑ πάντες ἀυτῇ σημαίνειν ἐπέτελλον·
# {'lause': 'Ja ühte ja sama pidid nad kõik temale andma märku.', 'märksõna': 'kõik [lemma: kõik]', 'tõlked': [{'grc': 'μιῇ...ἀυτῇ', 'ee': 'üht ja sama'}, {'grc': 'δέ', 'ee': 'ja'}, {'grc': 'ἑ', 'ee': 'temale'}, {'grc': 'πάντες', 'ee': 'kõik'}, {'grc': 'σημαίνειν', 'ee': 'andma märku'}, {'grc': 'ἐπέτελλον', 'ee': 'pidid'}]}
#
# 170 ἡμᾶς [lemma: ἐγώ] (pronoun) | plural.masculine.accusative
# οὐ γὰρ ἐλανθάνομεν ἡμᾶς αὐτοὺς ὄντες θνητοί·
# {'lause': 'Sest meid ei jää märkamata, [et] me ise surelikud oleme.', 'märksõna': 'meid (m. pl. acc.) [lemma: meie]', 'tõlked': [{'grc': 'οὐ', 'ee': 'ei'}, {'grc': 'γὰρ', 'ee': 'sest'}, {'grc': 'ἐλανθάνομεν', 'ee': '[jääb] märkamata'}, {'grc': 'ἡμᾶς', 'ee': 'meid'}, {'grc': 'αὐτοὺς', 'ee': 'ise'}, {'grc': 'ὄντες', 'ee': 'oleme'}, {'grc': 'θνητοί', 'ee': 'surelikud'}]}
#
# 171 ἐγώ [lemma: ἐγώ] (pronoun) | singular.masculine.nominative
# νικήσω δʼ ἐγώ.
# {'lause': 'Võidan, ma küll.', 'märksõna': 'ma [lemma: mina]', 'tõlked': [{'grc': 'νικήσω', 'ee': 'võidan'}, {'grc': 'δʼ', 'ee': 'küll'}, {'grc': 'ἐγώ', 'ee': 'ma'}]}
#
# 172 ἐνταῦθα [lemma: ἐνταῦθα] (adverb)
# κάλλιστα γὰρ ἐνταῦθα καθεδεῖσθαι καὶ μενεῖν.
# {'lause': 'Sest kõige parem on siin istuda ja jääda.', 'märksõna': 'siin [lemma: siin]', 'tõlked': [{'grc': 'κάλλιστα', 'ee': 'kõige parem'}, {'grc': 'γὰρ', 'ee': 'sest'}, {'grc': 'ἐνταῦθα', 'ee': 'siin'}, {'grc': 'καθεδεῖσθαι', 'ee': 'istuda'}, {'grc': 'καὶ', 'ee': 'ja'}, {'grc': 'μενεῖν', 'ee': 'jääda'}]}
#
# 173 ἄρα [lemma: ἄρα] (particle)
# ταὐτὸν ἄρα ἐστὶ καὶ δικαιοσύνη καὶ σωφροσύνη ;
# {'lause': 'Seega on [see] sama - nii õiglus kui ka mõõdukus.', 'märksõna': 'seega [lemma: seega]', 'tõlked': [{'grc': 'ταὐτὸν', 'ee': 'see'}, {'grc': 'ἄρα', 'ee': 'seega'}, {'grc': 'ἐστὶ', 'ee': 'on'}, {'grc': 'καὶ', 'ee': 'nii'}, {'grc': 'δικαιοσύνη', 'ee': 'õiglus'}, {'grc': 'καὶ', 'ee': 'kui ka'}, {'grc': 'σωφροσύνη', 'ee': 'mõõdukus'}]}
#
# 174 χρόνον [lemma: χρόνος] (noun) | singular.masculine.accusative
# καὶ τὰ μὲν ὧς ἤμελλε μετὰ χρόνον ἐκτελέεσθαι.
# {'lause': 'Ja need [asjad] pidid aja möödudes täide minema.', 'märksõna': 'aja [m. sg. gen.] [lemma: aeg]', 'tõlked': [{'grc': 'καὶ', 'ee': 'ja'}, {'grc': 'τὰ μὲν', 'ee': 'need [asjad]'}, {'grc': 'ὡς', 'ee': ''}, {'grc': 'ἤμελλε', 'ee': 'pidid'}, {'grc': 'μετὰ χρόνον', 'ee': 'aja möödudes'}, {'grc': 'ἐκτελέεσθαι', 'ee': 'täide minema'}]}
#
# 175 οὔ [lemma: οὐ] (adverb)
# τὸν ἄνδρʼ ἐκεῖνον οὔ τι μὴ λίπω ποτέ.
# {'lause': 'Seda meest ma mitte kunagi ei jäta.', 'märksõna': 'mitte [lemma: mitte]', 'tõlked': [{'grc': 'τὸν ἄνδρʼ ἐκεῖνον', 'ee': 'seda meest'}, {'grc': 'οὔ', 'ee': 'mitte'}, {'grc': 'τι', 'ee': 'kunagi'}, {'grc': 'μὴ λίπω', 'ee': 'ei jäta'}, {'grc': 'ποτέ', 'ee': ''}]}
#
# 176 σοι [lemma: σύ] (pronoun) | singular.feminine.dative
# τί σοι πέπρωται πρᾶγμα πλὴν τεύχειν κακά ;
# {'lause': 'Mis on sulle määratud asja peale kurja valmistama?', 'märksõna': 'sulle [lemma: sina]', 'tõlked': [{'grc': 'τί', 'ee': 'mis'}, {'grc': 'σοι', 'ee': 'sulle'}, {'grc': 'πέπρωται', 'ee': 'on määratud'}, {'grc': 'πρᾶγμα', 'ee': 'asja'}, {'grc': 'πλὴν', 'ee': 'peale'}, {'grc': 'τεύχειν', 'ee': 'valmistama'}, {'grc': 'κακά', 'ee': 'kurja'}]}
#
# 177 πόλεως [lemma: πόλις] (noun) | singular.feminine.genitive
# ἰὼ πόλεως ἀγοὶ πρόμοι, δάμναμαι.
# {'lause': 'Oo linna juhid, kaitsejad, olen hukkunud!', 'märksõna': 'linna (s. gen. sg.) [lemma: linn]', 'tõlked': [{'grc': 'ἰὼ', 'ee': 'oo'}, {'grc': 'πόλεως', 'ee': 'linna'}, {'grc': 'ἀγοὶ πρόμοι', 'ee': 'juhid, kaitsejad'}, {'grc': 'δάμναμαι', 'ee': 'olen hukkunud'}]}
#
# 178 ἐὰν [lemma: ἐάν] (subordinating_conjunction)
# ἐὰν δέ ποι ἐξίῃ, οὐδεμία αὐτοῦ ἀπολείπεται·
# {'lause': 'Kui aga sa välja lähed, siis mitte miski sinust maha ei jää.', 'märksõna': 'kui [lemma: kui]', 'tõlked': [{'grc': 'ἐὰν', 'ee': 'kui'}, {'grc': 'δέ', 'ee': 'aga'}, {'grc': 'ποι', 'ee': '[siis]'}, {'grc': 'ἐξίῃ', 'ee': 'lähed'}, {'grc': 'οὐδεμία', 'ee': 'mitte miski'}, {'grc': 'αὐτοῦ', 'ee': 'sinust'}, {'grc': 'ἀπολείπεται', 'ee': 'jää'}]}
#
# 179 ὑμῶν [lemma: ὑμεῖς] (pronoun) | plural.masculine.genitive
# ὑφʼ ὑμῶν καὶ τῶν δικαίων τυγχάνειν·
# {'lause': '[Seda] teie ja õiglaste käest saavutada.', 'märksõna': 'teie (m. gen. pl.) [lemma: teie]', 'tõlked': [{'grc': 'ὑφʼ', 'ee': '[Seda]'}, {'grc': 'ὑμῶν', 'ee': 'teie'}, {'grc': 'καὶ', 'ee': 'ja'}, {'grc': 'τῶν δικαίων', 'ee': 'õiglaste'}, {'grc': 'τυγχάνειν', 'ee': 'saavutada'}]}
#
# 180 ἅμα [lemma: ἅμα] (adverb)
# τοὶ δʼ ἅμα πάντες ἤειραν κεφαλὰς ἐσορώμενοι·
# {'lause': 'Need aga kõik üheaegselt tõstsid päid, vaadates.', 'märksõna': 'üheaegselt [lemma: üheaegselt]', 'tõlked': [{'grc': 'τοὶ δʼ', 'ee': 'need aga'}, {'grc': 'ἅμα', 'ee': 'üheaegselt'}, {'grc': 'πάντες', 'ee': 'kõik'}, {'grc': 'ἤειραν κεφαλὰς', 'ee': 'tõstsid päid'}, {'grc': 'ἐσορώμενοι', 'ee': 'vaadates'}]}
#
# 181 τοῦτον [lemma: οὗτος] (adjective) | singular.masculine.accusative
# ταῦτα μὲν τοῦτον τὸν ὄρνιν λέγουσι ποιέειν.
# {'lause': 'Seda kõike väidavad nad sellel linnul olevat.', 'märksõna': 'sellel [m. sg. acc.][lemma: see]', 'tõlked': [{'grc': 'ταῦτα', 'ee': 'seda kõike'}, {'grc': 'μὲν', 'ee': '[osakeste vaste puudub]'}, {'grc': 'τοῦτον τὸν ὄρνιν', 'ee': 'sellel linnul'}, {'grc': 'λέγουσι', 'ee': 'väidavad'}, {'grc': 'ποιέειν', 'ee': 'olevat'}]}
#
# 182 ἐστὶ [lemma: εἰμί] (auxiliary) | finite; present.active.indicative.third.singular
# νῦν δὲ πρέπον ἐστὶ καὶ ὑμᾶς ἀκοῦσαί μου.
# {'lause': 'Nüüd aga on kohane ka teid mind kuulata.', 'märksõna': 'on [lemma: olema]', 'tõlked': [{'grc': 'νῦν', 'ee': 'nüüd'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'πρέπον ἐστὶ', 'ee': 'on kohane'}, {'grc': 'καὶ', 'ee': 'ka'}, {'grc': 'ὑμᾶς', 'ee': 'teid'}, {'grc': 'ἀκοῦσαί μου', 'ee': 'mind kuulata'}]}
#
# 183 ἔνθα [lemma: ἔνθα] (adverb)
# ὧς φάσαν ἔνθα καὶ ἔνθα κατὰ πτόλιν·
# {'lause': 'Nõnda öelnud, seal ja seal iga linna kohta.', 'märksõna': 'seal [lemma: seal]', 'tõlked': [{'grc': 'ὧς', 'ee': 'nõnda'}, {'grc': 'φάσαν', 'ee': 'öelnud'}, {'grc': 'ἔνθα', 'ee': 'seal'}, {'grc': 'καὶ', 'ee': 'ja'}, {'grc': 'ἔνθα', 'ee': 'seal'}, {'grc': 'κατὰ πτόλιν', 'ee': 'iga linna kohta'}]}
#
# 184 ταύτην [lemma: οὗτος] (adjective) | singular.feminine.accusative
# ταύτην μὲν οὕτω φροντίδʼ ἐκποδὼν λέγω.
# {'lause': 'Seda ma siis ütlen, et mure on jalust ära.', 'märksõna': 'seda (f. sg. acc.) [lemma: see]', 'tõlked': [{'grc': 'ταύτην', 'ee': 'seda'}, {'grc': 'μὲν', 'ee': 'siis'}, {'grc': 'οὕτω', 'ee': 'nüüd'}, {'grc': 'φροντίδʼ', 'ee': '[on] mure'}, {'grc': 'ἐκποδὼν', 'ee': 'jalust ära'}, {'grc': 'λέγω', 'ee': 'ütlen'}]}
#
# 185 ἄν [lemma: ἄν] (particle)
# ἀμφοτέρους ἔγωγʼ ἄν, ἔφη.
# {'lause': '[Mina] mõlemaid armastaksin, ta ütles.', 'märksõna': 'küll [lemma: küll]', 'tõlked': [{'grc': 'ἀμφοτέρους', 'ee': 'mõlemaid'}, {'grc': 'ἔγωγʼ', 'ee': '[Mina]'}, {'grc': 'ἄν', 'ee': 'küll'}, {'grc': 'ἔφη', 'ee': 'ütles'}]}
#
# 186 τίς [lemma: τις] (pronoun) | singular.masculine.nominative
# Ζεῦ ἄνα, τίς Πελίαο νόος ;
# {'lause': 'Zeus, valitseja, milline on Peliase meel?', 'märksõna': 'milline [lemma: milline]', 'tõlked': [{'grc': 'Ζεῦ', 'ee': 'Zeus'}, {'grc': 'ἄνα', 'ee': 'valitseja'}, {'grc': 'τίς', 'ee': 'milline'}, {'grc': 'Πελίαο', 'ee': 'Peliase'}, {'grc': 'νόος', 'ee': 'meel'}]}
#
# 187 ἐγὼ [lemma: ἐγώ] (pronoun) | singular.feminine.nominative
# ἐγὼ δʼ ἰάχοντος ἄκουσα.
# {'lause': 'Mina kuulsin karjuvat.', 'märksõna': 'mina [lemma: mina]', 'tõlked': [{'grc': 'ἐγὼ', 'ee': 'mina'}, {'grc': 'δʼ ἰάχοντος', 'ee': 'karjuvat'}, {'grc': 'ἄκουσα', 'ee': 'kuulsin'}]}
#
# 188 ἐγένετο [lemma: γίγνομαι] (verb) | finite; past.middle.indicative.third.singular
# τὰ δὴ καὶ ἐγένετο.
# {'lause': 'See siis ka sündis.', 'märksõna': 'sündis [lemma: sündima]', 'tõlked': [{'grc': 'τὰ', 'ee': 'see'}, {'grc': 'δὴ', 'ee': 'siis'}, {'grc': 'καὶ', 'ee': 'ka'}, {'grc': 'ἐγένετο', 'ee': 'sündis'}]}
#
# 189 εὐθὺς [lemma: εὐθύς] (adverb)
# καὶ εὐθὺς τροχάζων ἡγεῖτο.
# ...
#
# 480 ἐγένοντο [lemma: γίγνομαι] (verb) | finite; past.middle.indicative.third.plural
# καὶ οὕτω ἔτι αἱ πόλιες ἐγένοντο ὑψηλότεραι :
# {'lause': 'Ja nõnda said linnad veelgi kõrgemaks.', 'märksõna': 'said [lemma: saama]', 'tõlked': [{'grc': 'καὶ', 'ee': 'ja'}, {'grc': 'οὕτω', 'ee': 'nõnda'}, {'grc': 'ἔτι', 'ee': 'veelgi'}, {'grc': 'αἱ πόλιες', 'ee': 'linnad'}, {'grc': 'ἐγένοντο', 'ee': 'said'}, {'grc': 'ὑψηλότεραι', 'ee': 'kõrgemaks'}]}
#
# 481 ἅτε [lemma: ἅτε] (adverb)
# ἅτε οὐ παραγενόμενος τῷ προτέρῳ λόγῳ.
# {'lause': '[Kuna] mitte olles eelmisele jutule [kohale jõudnud].', 'märksõna': '[Kuna] [lemma: kuna]', 'tõlked': [{'grc': 'ἅτε', 'ee': '[Kuna]'}, {'grc': 'οὐ', 'ee': 'mitte'}, {'grc': 'παραγενόμενος', 'ee': 'olles [kohale jõudnud]'}, {'grc': 'τῷ προτέρῳ λόγῳ', 'ee': 'eelmisele jutule'}]}
#
# 482 τοίνυν [lemma: τοίνυν] (particle)
# δυοῖν μὲν τοίνυν λόγοιν ἀκηκόατε·
# {'lause': 'Te olete nüüd siis kahe kõne kuulnud.', 'märksõna': 'nüüd siis [lemma: nüüd siis]', 'tõlked': [{'grc': 'δυοῖν', 'ee': 'kahe'}, {'grc': 'μὲν', 'ee': ''}, {'grc': 'τοίνυν', 'ee': 'nüüd siis'}, {'grc': 'λόγοιν', 'ee': 'kõne'}, {'grc': 'ἀκηκόατε', 'ee': 'olete kuulnud'}]}
#
# 483 αὐτὰ [lemma: αὐτός] (pronoun) | plural.neuter.accusative
# τὰ περὶ Αἴγυπτον ὦν καὶ τοῖσι λέγουσι αὐτὰ πείθομαι
# {'lause': 'Asju, mis puudutavad Egiptust,  usaldan ma neid ka neile, kes neid räägivad.', 'märksõna': 'neid (n. acc. pl.) [lemma: see]', 'tõlked': [{'grc': 'τὰ', 'ee': 'asju'}, {'grc': 'περὶ Αἴγυπτον', 'ee': 'mis puudutavad Egiptust'}, {'grc': 'ὦν', 'ee': ','}, {'grc': 'καὶ', 'ee': 'ka'}, {'grc': 'τοῖσι ... λέγουσι', 'ee': 'neile, kes neid räägivad'}, {'grc': 'αὐτὰ', 'ee': 'neid'}, {'grc': 'πείθομαι', 'ee': 'usaldan ma'}]}
#
# 484 διʼ [lemma: διʼ] (adverb)
# ὁ δὲ τοσοῦτον ὑπερεῖδε τὸ διʼ ἐμέ·
# {'lause': 'Tema aga niivõrd [mind] minust kõrgemal pidas.', 'märksõna': 'kõrgemal [lemma: kõrgemal]', 'tõlked': [{'grc': 'ὁ', 'ee': 'tema'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'τοσοῦτον', 'ee': 'niivõrd'}, {'grc': 'ὑπερεῖδε', 'ee': 'kõrgemal pidas'}, {'grc': 'τὸ', 'ee': '[mind]'}, {'grc': 'διʼ', 'ee': 'minust'}, {'grc': 'ἐμέ', 'ee': ''}]}
#
# 485 αὐτὴν [lemma: αὐτός] (pronoun) | singular.feminine.accusative
# τέλος δὲ ἀποδιδοῦσαν αὐτὴν εἰπεῖν
# {'lause': 'Lõpuks aga ütlesid nad, et ta andis iseenda ära.', 'märksõna': 'iseenda [lemma: ise]', 'tõlked': [{'grc': 'τέλος', 'ee': 'lõpuks'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'ἀποδιδοῦσαν', 'ee': 'ütlesid'}, {'grc': 'αὐτὴν', 'ee': 'iseenda'}, {'grc': 'εἰπεῖν', 'ee': 'ära andis'}]}
#
# 486 ὑπʼ [lemma: ὑπʼ] (adverb)
# ἀλλά μιν ἔφθη Τῖφυς ὑπʼ εἰρεσίῃ βαρύθουσαν ἀγχαλάσας·
# {'lause': 'Aga teda jõudis enne Tüphus, (sõudmisega) kurnastatuna lämbudes.', 'märksõna': 'lämbudes [lemma: lämbuma]', 'tõlked': [{'grc': 'ἀλλά', 'ee': 'aga'}, {'grc': 'μιν', 'ee': 'teda'}, {'grc': 'ἔφθη', 'ee': 'jõudis enne'}, {'grc': 'Τῖφυς', 'ee': 'Tüphus'}, {'grc': 'ὑπʼ  εἰρεσίῃ βαρύθουσαν', 'ee': '(sõudmisega) kurnastatuna'}, {'grc': 'ἀγχαλάσας', 'ee': 'lämbudes'}]}
#
# 487 ὄντος [lemma: εἰμί] (auxiliary) | participle; present.active.singular.genitive
# νοσήματος δὲ μὴ ὄντος οὐδὲν δεῖ φαρμάκου.
# {'lause': 'Haigust aga mitte olles pole üldse [mingit] ravimit vaja.', 'märksõna': 'olles [lemma: olema]', 'tõlked': [{'grc': 'νοσήματος', 'ee': 'haigust'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'μὴ ὄντος', 'ee': 'mitte olles'}, {'grc': 'οὐδὲν', 'ee': 'üldse'}, {'grc': 'δεῖ', 'ee': '[on] vaja'}, {'grc': 'φαρμάκου', 'ee': 'ravimit'}]}
#
# 488 μεθʼ [lemma: μεθʼ] (verb) | participle; present.active.singular.nominative
# ἡ χάρις μεθʼ ὑμῶν.
# {'lause': 'Arm [on] teiega.', 'märksõna': '[lemma: olema]', 'tõlked': [{'grc': 'ἡ', 'ee': '[see]'}, {'grc': 'χάρις', 'ee': 'arm'}, {'grc': 'μεθʼ ὑμῶν', 'ee': 'teiega'}]}
#
# 489 ἑαυτὸν [lemma: ἑαυτοῦ] (pronoun) | singular.masculine.accusative
# παράδειγμα μὲν δὴ τοιοῦτον ἑαυτὸν παρείχετο.
# {'lause': 'Näiteks siis ta ennast [selliseks] esitas.', 'märksõna': 'ennast (sg. m. acc.) [lemma: tema]', 'tõlked': [{'grc': 'παράδειγμα', 'ee': 'näiteks'}, {'grc': 'μὲν δὴ', 'ee': 'siis'}, {'grc': 'τοιοῦτον', 'ee': '[selliseks]'}, {'grc': 'ἑαυτὸν', 'ee': 'ennast'}, {'grc': 'παρείχετο', 'ee': 'esitas'}]}
#
# 490 ἔλεγον [lemma: λέγω] (verb) | finite; past.active.indicative.third.plural
# ταῦτα δὲ ἐξευρεῖν ἐκ τῶν ἀστέρων ἔλεγον :
# {'lause': 'Need asjad aga [nad] väitsid tähtede järgi olevat leidnud.', 'märksõna': 'väitsid [lemma: väitma]', 'tõlked': [{'grc': 'ταῦτα', 'ee': 'need asjad'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'ἐξευρεῖν', 'ee': 'leida'}, {'grc': 'ἐκ τῶν ἀστέρων', 'ee': 'tähtede järgi'}, {'grc': 'ἔλεγον', 'ee': 'väitsid'}]}
#
# 491 ἄλλην [lemma: ἄλλος] (adjective) | singular.feminine.accusative
# οὔτε ἄλλην οὐδεμίαν ἰδέσθαι τῶν συγκατημενέων γυναικῶν.
# {'lause': 'Ei ühtki teist naist nähtud olevat istuvat koos.', 'märksõna': 'teist (f. sg. acc.) [lemma: teine]', 'tõlked': [{'grc': 'οὔτε', 'ee': 'ei'}, {'grc': 'ἄλλην', 'ee': 'ühtki teist'}, {'grc': 'οὐδεμίαν', 'ee': ''}, {'grc': 'ἰδέσθαι', 'ee': 'nähtud olevat'}, {'grc': 'τῶν  συγκατημενέων γυναικῶν', 'ee': 'naist istuvat koos'}]}
#
# 492 στρατὸν [lemma: στρατός] (noun) | singular.masculine.accusative
# στρατὸν μὲν τοσοῦ - τον τάλας πέπληγμαι.
# {'lause': 'Väesalga poolest küll olen ma, õnnetu, nii rängalt löödud.', 'märksõna': 'väesalga (s. gen. sg.) [lemma: vägi]', 'tõlked': [{'grc': 'στρατὸν', 'ee': 'väesalga'}, {'grc': 'μὲν', 'ee': 'küll'}, {'grc': 'τοσοῦτον', 'ee': 'nii'}, {'grc': 'τάλας', 'ee': 'õnnetu'}, {'grc': 'πέπληγμαι', 'ee': 'olen löödud'}]}
#
# 493 θεοὺς [lemma: θεός] (noun) | plural.masculine.accusative
# ἦ ῥα θεοὺς ὀλοῇσι παρήλιτες ἀφραδίῃσιν μαντοσύνας δεδαώς ;
# {'lause': 'Kas [sina] tõesti jumalaid oled petnud hukutavate rumalustega ennustusi teades?', 'märksõna': 'jumalaid (m. acc. pl.) [lemma: jumal]', 'tõlked': [{'grc': 'ἦ', 'ee': 'kas'}, {'grc': 'ῥα', 'ee': '[sina] tõesti'}, {'grc': 'θεοὺς', 'ee': 'jumalaid'}, {'grc': 'ὀλοῇσι ... ἀφραδίῃσιν', 'ee': 'hukutavate rumalustega'}, {'grc': 'παρήλιτες', 'ee': 'oled petnud'}, {'grc': 'μαντοσύνας', 'ee': 'ennustusi'}, {'grc': 'δεδαώς', 'ee': 'teades'}]}
#
# 494 ἑαυτῶν [lemma: ἑαυτοῦ] (pronoun) | plural.masculine.genitive
# σωφρονοῦσιν οὖν οὐ τὰ ἑαυτῶν μόνον ποιοῦντες ;
# {'lause': 'Nad on siis mõistlikud mitte ainult oma asju tehes,', 'märksõna': 'oma (m. gen. pl.) [lemma: oma]', 'tõlked': [{'grc': 'σωφρονοῦσιν', 'ee': 'on mõistlikud'}, {'grc': 'οὖν', 'ee': 'siis'}, {'grc': 'οὐ', 'ee': 'mitte'}, {'grc': 'τὰ ἑαυτῶν', 'ee': 'oma asju'}, {'grc': 'μόνον', 'ee': 'ainult'}, {'grc': 'ποιοῦντες', 'ee': 'tehes'}]}
#
# 495 ἕκαστος [lemma: ἕκαστος] (adjective) | singular.masculine.nominative
# τὴν δὲ μίαν ἕκαστος σιτοποιὸν ἐξαιρέετο :
# {'lause': 'Ühe aga igaüks valis endale viljakandjaks:', 'märksõna': 'igaüks [lemma: igaüks]', 'tõlked': [{'grc': 'τὴν δὲ μίαν', 'ee': 'ühe aga'}, {'grc': 'ἕκαστος', 'ee': 'igaüks'}, {'grc': 'σιτοποιὸν', 'ee': 'viljakandjaks'}, {'grc': 'ἐξαιρέετο', 'ee': 'valis'}, {'grc': ':', 'ee': ':'}]}
#
# 496 οἵ [lemma: ὁ] (determiner) | plural.masculine.nominative
# οὐ μέντοι οἵ γε Σάμιοι ἐποίησαν ταῦτα.
# {'lause': 'Mitte aga need [saarlased] Saamiselt [ei teinud] neid [asju].', 'märksõna': 'need (m. nom. pl.) [lemma: see]', 'tõlked': [{'grc': 'οὐ μέντοι', 'ee': 'mitte aga'}, {'grc': 'οἵ γε', 'ee': 'need'}, {'grc': 'Σάμιοι', 'ee': '[saarlased] Saamiselt'}, {'grc': 'ἐποίησαν', 'ee': '[ei teinud]'}, {'grc': 'ταῦτα', 'ee': 'neid [asju]'}]}
#
# 497 Καῖσαρ [lemma: Καῖσαρ] (noun) | singular.feminine.nominative
# ὁ δὲ Καῖσαρ ἀντιπράξειν τὴν βουλὴν ὑπονοῶν
# {'lause': 'Aga Caesar, [sest] ta kahtlustas senati [plaani],', 'märksõna': 'Caesar [lemma: Caesar]', 'tõlked': [{'grc': 'ὁ', 'ee': '[see]'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'Καῖσαρ', 'ee': 'Caesar'}, {'grc': 'ἀντιπράξειν', 'ee': 'kahtlustas'}, {'grc': 'τὴν βουλήν', 'ee': 'senati [plaani]'}, {'grc': 'ὑπονοῶν', 'ee': '[sest] ta'}]}
#
# 498 θεοῖς [lemma: θεός] (noun) | plural.masculine.dative
# ὅσσα δʼ ὄρωρε θεοῖς φίλον, οὐκ ἐπικεύσω.
# {'lause': 'Mis jumalatele armas on tõusnud, seda ma ei varja.', 'märksõna': 'jumalatele (m. dat. pl.) [lemma: jumal]', 'tõlked': [{'grc': 'ὅσσα', 'ee': 'mis'}, {'grc': 'δʼ ὄρωρε', 'ee': 'on tõusnud'}, {'grc': 'θεοῖς', 'ee': 'jumalatele'}, {'grc': 'φίλον', 'ee': 'armas'}, {'grc': 'οὐκ', 'ee': 'ei'}, {'grc': 'ἐπικεύσω', 'ee': 'varja'}]}
#
# 499 μάλιστα [lemma: μάλα] (adverb)
# ἀλλὰ ποία μάλιστα ;
# {'lause': 'Aga millised siis kõige enam?', 'märksõna': 'kõige enam [lemma: palju]', 'tõlked': [{'grc': 'ἀλλὰ', 'ee': 'aga'}, {'grc': 'ποία', 'ee': 'millised'}, {'grc': 'μάλιστα', 'ee': 'kõige enam'}]}
#
# 500 τόδε [lemma: ὅδε] (pronoun) | singular.neuter.accusative
# ἀλλὰ τόδε σκοπεῖτε·
# {'lause': 'Aga seda te kaaluge!', 'märksõna': 'seda [lemma: see]', 'tõlked': [{'grc': 'ἀλλὰ', 'ee': 'aga'}, {'grc': 'τόδε', 'ee': 'seda'}, {'grc': 'σκοπεῖτε', 'ee': 'kaaluge'}]}
#
# 501 Ἕλληνες [lemma: ἕλλην] (noun) | plural.masculine.nominative
# καὶ τέσσερας ἵππους συζευγνύναι παρὰ Λιβύων οἱ Ἕλληνες
# {'lause': 'Ja neli hobust rakendada Liibüalaste poolt [olid] Kreeklased.', 'märksõna': 'Kreeklased [lemma: kreeklane]', 'tõlked': [{'grc': 'καὶ', 'ee': 'ja'}, {'grc': 'τέσσερας', 'ee': 'neli'}, {'grc': 'ἵππους', 'ee': 'hobust'}, {'grc': 'συζευγνύναι', 'ee': 'rakendada'}, {'grc': 'παρὰ Λιβύων', 'ee': 'Liibüalaste poolt'}, {'grc': 'οἱ', 'ee': '[olid]'}, {'grc': 'Ἕλληνες', 'ee': 'Kreeklased'}]}
#
# 502 πέντε [lemma: πέντε] (numeral) | None.None.None
# οὗτος δὲ ὕστατος κατεργάσθη τῶν πέντε ἀγώνων.
# {'lause': 'Aga tema viimasena saavutas viiest võistlusest [võidu].', 'märksõna': 'viis [lemma: viis]', 'tõlked': [{'grc': 'οὗτος', 'ee': 'tema'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'ὕστατος', 'ee': 'viimasena'}, {'grc': 'κατεργάσθη', 'ee': 'saavutas'}, {'grc': 'τῶν πέντε ἀγώνων', 'ee': 'viiest võistlusest'}, {'grc': '', 'ee': '[võidu]'}]}
#
# 503 ταῦτα [lemma: οὗτος] (pronoun) | plural.neuter.nominative
# ἀλλὰ ταῦτα μὲν εἰκασμῷ λέλεκται.
# {'lause': 'Aga see on öeldud (sõna-sõnalt: räägitud) küll kujundlikult.', 'märksõna': 'see [lemma: see]', 'tõlked': [{'grc': 'ἀλλὰ', 'ee': 'aga'}, {'grc': 'ταῦτα', 'ee': 'see'}, {'grc': 'μὲν', 'ee': 'küll'}, {'grc': 'εἰκασμῷ', 'ee': 'kujundlikult'}, {'grc': 'λέλεκται', 'ee': 'öeldud'}]}
#
# 504 ἧττον [lemma: ἥσσων] (adjective) | singular.neuter.accusative
# οὐδενὸς δὲ ἧττον ἐπετάραττεν ἡ πολυαρχία τὰ πραττόμενα.
# {'lause': 'Aga mitte vähem [kui keegi teine] ei häirinud valitsus tegusid.', 'märksõna': 'vähem [lemma: vähe]', 'tõlked': [{'grc': 'οὐδενὸς', 'ee': '[kui] keegi [teine]'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'ἧττον', 'ee': 'vähem'}, {'grc': 'ἐπετάραττεν', 'ee': 'häiris'}, {'grc': 'ἡ πολυαρχία', 'ee': 'valitsus'}, {'grc': 'τὰ πραττόμενα', 'ee': 'tegusid'}]}
#
# 505 μάχην [lemma: μάχη] (noun) | singular.feminine.accusative
# μετὰ δὲτὴν μάχην ἐκείνην
# {'lause': 'Aga pärast seda lahingut', 'märksõna': 'lahingut (s. gen. sg.) [lemma: lahing]', 'tõlked': [{'grc': 'μετὰ', 'ee': 'pärast'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'τὴν', 'ee': 'seda'}, {'grc': 'μάχην', 'ee': 'lahingut'}, {'grc': 'ἐκείνην', 'ee': 'seda'}]}
#
# 506 μὴν [lemma: μήν] (particle)
# καὶ μὴν Κάνωβον κἀπὶ Μέμφιν ἵκετο.
# {'lause': 'Ja [ta] saabus tõepoolest nii Kanoposet kui ka Memfisesse.', 'märksõna': 'tõepoolest [lemma: tõepoolest]', 'tõlked': [{'grc': 'καὶ', 'ee': 'ja'}, {'grc': 'μὴν', 'ee': 'tõepoolest'}, {'grc': 'Κάνωβον', 'ee': 'Kanoposet'}, {'grc': 'κἀπὶ', 'ee': 'nii ... kui ka'}, {'grc': 'Μέμφιν', 'ee': 'Memfisesse'}, {'grc': 'ἵκετο', 'ee': 'saabus'}]}
#
# 507 λέγοντες [lemma: λέγω] (verb) | participle; present.active.plural.nominative
# λέγοντες δὲ ταῦτα οὐκ ὀρθῶς λέγουσι.
# {'lause': 'Seda öeldes nad ei räägi õigesti.', 'märksõna': 'öeldes [lemma: ütlema]', 'tõlked': [{'grc': 'λέγοντες', 'ee': 'öeldes'}, {'grc': 'δὲ', 'ee': '[aga]'}, {'grc': 'ταῦτα', 'ee': 'seda'}, {'grc': 'οὐκ', 'ee': 'ei'}, {'grc': 'ὀρθῶς', 'ee': 'õigesti'}, {'grc': 'λέγουσι', 'ee': 'räägivad'}]}
#
# 508 ἔσεσθαι [lemma: εἰμί] (auxiliary) | infinitive; future.middle
# οἷος τε ἔσεσθαι ἄρχειν οὔτε ἄλλον οὐδένα οὐδαμῶν :
# {'lause': '[Keegi] ei suuda valitseda ei kedagi teist ega ka mitte kusagilt.', 'märksõna': 'suuda [lemma: suutma]', 'tõlked': [{'grc': 'οἷος τε', 'ee': '[Keegi] ei suuda'}, {'grc': 'ἔσεσθαι', 'ee': 'suuda'}, {'grc': 'ἄρχειν', 'ee': 'valitseda'}, {'grc': 'οὔτε ... οὔτε', 'ee': 'ei ... ega ka'}, {'grc': 'ἄλλον', 'ee': 'kedagi teist'}, {'grc': 'οὐδένα', 'ee': 'mitte kedagi'}, {'grc': 'οὐδαμῶν', 'ee': 'kusagilt'}, {'grc': ':', 'ee': ''}]}
#
# 509 χεῖρας [lemma: χείρ] (noun) | plural.feminine.accusative
# τῶ καὶ τεύχεα δύντες ἐπὶ σφίσι χεῖρας ἄειραν.
# Could not translate sentence 1477; Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. Please check the `candidate.safety_ratings` to determine if the response was blocked.
#
# 510 πατέρα [lemma: πατήρ] (noun) | singular.masculine.accusative
# αὐτὸς δʼ ἔδησε πατέρα πρεσβύτην Κρόνον.
# {'lause': 'Tema ise aheldas [oma] isa, vana Kronost.', 'märksõna': 'isa [lemma: isa]', 'tõlked': [{'grc': 'αὐτὸς', 'ee': 'tema ise'}, {'grc': 'δʼ', 'ee': ''}, {'grc': 'ἔδησε', 'ee': 'aheldas'}, {'grc': 'πατέρα', 'ee': 'isa'}, {'grc': 'πρεσβύτην', 'ee': 'vana'}, {'grc': 'Κρόνον', 'ee': 'Kronost'}]}
#
# 511 ἁπάντων [lemma: ἅπας] (adjective) | plural.masculine.genitive
# τίνα δὲ ἁπάντων κάλλιον προτιμᾶν ἢ τὸν ἀδελφόν ;
# {'lause': 'Aga keda kõigist on ilusam eelistada kui venda?', 'märksõna': 'kõigist (m. gen. pl.) [lemma: kõik]', 'tõlked': [{'grc': 'τίνα', 'ee': 'keda'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'ἁπάντων', 'ee': 'kõigist'}, {'grc': 'κάλλιον', 'ee': 'ilusam'}, {'grc': 'προτιμᾶν', 'ee': 'eelistada'}, {'grc': 'ἢ', 'ee': 'kui'}, {'grc': 'τὸν ἀδελφόν', 'ee': 'venda'}]}
#
# 512 αὑτῶν [lemma: ἑαυτοῦ] (pronoun) | plural.masculine.genitive
# τούτων δὲ πραχθέντων ἀπεχώρησαν εἰς τὸ αὑτῶν στρατόπεδον.
# {'lause': 'Aga kui need [asjad] olid tehtud, läksid nad tagasi oma leeri.', 'märksõna': 'oma (m. gen. pl.) [lemma: oma]', 'tõlked': [{'grc': 'τούτων', 'ee': 'need [asjad]'}, {'grc': 'δὲ', 'ee': 'aga'}, {'grc': 'πραχθέντων', 'ee': 'kui ... olid tehtud'}, {'grc': 'ἀπεχώρησαν', 'ee': 'läksid tagasi'}, {'grc': 'εἰς', 'ee': '[leeri]'}, {'grc': 'τὸ ... στρατόπεδον', 'ee': 'oma leeri'}, {'grc': 'αὑτῶν', 'ee': 'oma'}]}
#
# 513 ἔργων [lemma: ἔργον] (noun) | plural.neuter.genitive
# παλαιῶν μέν νυν ἔργων ἅλις ἔστω :
# {'lause': 'Vanadest aga nüüd (olgu) töödest küllalt :', 'märksõna': 'töödest (n. gen. pl.) [lemma: töö]', 'tõlked': [{'grc': 'παλαιῶν', 'ee': 'vanadest'}, {'grc': 'μέν', 'ee': 'aga'}, {'grc': 'νυν', 'ee': 'nüüd'}, {'grc': 'ἔργων', 'ee': 'töödest'}, {'grc': 'ἅλις', 'ee': 'küllalt'}, {'grc': 'ἔστω', 'ee': '(olgu)'}, {'grc': ':', 'ee': ':'}]}
#
# 514 γένοιτο [lemma: γίγνομαι] (verb) | finite; past.middle.optative.third.singular
# πανώλεθρος δʼ οὔποτʼ ἂν γένοιτο.
# {'lause': 'Täiesti hukkunuks [see] mitte kunagi ei saaks.', 'märksõna': 'saaks [lemma: saama]', 'tõlked': [{'grc': 'πανώλεθρος', 'ee': 'täiesti hukkunuks'}, {'grc': 'δʼ', 'ee': '[see]'}, {'grc': 'οὔποτʼ', 'ee': 'mitte kunagi'}, {'grc': 'ἂν', 'ee': 'ei'}, {'grc': 'γένοιτο', 'ee': 'saaks'}]}
#
# 515 πολιτῶν [lemma: πολίτης] (noun) | plural.masculine.genitive
# ἐκ τῶν δὲ τοῦδε χρημάτων πειράσομαι ἄρχειν πολιτῶν·
# {'lause': 'Ja nende rahade abil ma püüan kodanikke valvata.', 'märksõna': 'kodanikke (m. gen. pl.) [lemma: kodanik]', 'tõlked': [{'grc': 'ἐκ τῶν ... χρημάτων', 'ee': 'nende rahade abil'}, {'grc': 'δὲ', 'ee': 'ja'}, {'grc': 'τοῦδε', 'ee': 'nende'}, {'grc': 'πειράσομαι', 'ee': 'ma püüan'}, {'grc': 'ἄρχειν', 'ee': 'valvata'}, {'grc': 'πολιτῶν', 'ee': 'kodanikke'}]}
#
# 516 οὗτοι [lemma: οὗτος] (adjective) | plural.masculine.nominative
# οὗτοι εἰσὶ οἱ πρῶτοι θρησκεύσαντες.
# {'lause': 'Need on need esimesed, [kes] usu teenimist alustasid (θρησκεύσαντες).', 'märksõna': 'need [lemma: see]', 'tõlked': [{'grc': 'οὗτοι', 'ee': 'need'}, {'grc': 'εἰσὶ', 'ee': 'on'}, {'grc': 'οἱ', 'ee': 'need'}, {'grc': 'πρῶτοι', 'ee': 'esimesed'}, {'grc': 'θρησκεύσαντες', 'ee': 'usu teenimist alustasid'}]}

# %%
persist_tables(df_sents, df_words, df_sents_ee, persist_all=True)

# %%
df_sents_ee
# Out:
#                                                      ee_phrase  \
# ee_sent_idx
# 0            Ning need kirjalikud näidised loetakse teile e...
# 1                     Aga ka nende tunnistajaid toon ma teile.
# 2            Sest nad on kirja pannud igaühe [neist] kolm j...
# 3                   Ja mina imetlesin tema vastust ja ütlesin:
# 4                            See on looduses (kõige) liikuvam.
# ...                                                        ...
# 497          Aga kui need [asjad] olid tehtud, läksid nad t...
# 498                 Vanadest aga nüüd (olgu) töödest küllalt :
# 499             Täiesti hukkunuks [see] mitte kunagi ei saaks.
# 500           Ja nende rahade abil ma püüan kodanikke valvata.
# 501          Need on need esimesed, [kes] usu teenimist alu...
#
#                                             ee_target  \
# ee_sent_idx
# 0                                  ning [lemma: ning]
# 1                                    aga [lemma: aga]
# 2                               ja, isegi [lemma: ja]
# 3                    selle (f. acc. sg.) [lemma: see]
# 4                                -s, -l [lemma: sees]
# ...                                               ...
# 497                    oma (m. gen. pl.) [lemma: oma]
# 498                töödest (n. gen. pl.) [lemma: töö]
# 499                              saaks [lemma: saama]
# 500          kodanikke (m. gen. pl.) [lemma: kodanik]
# 501                                 need [lemma: see]
#
#                                                       ee_words  grc_sent_idx  \
# ee_sent_idx
# 0            [{'ee': 'loetakse ette', 'grc': 'ἀναγνωσθήσοντ...            31
# 1            [{'ee': 'tunnistajaid', 'grc': 'μάρτυρας'}, {'...            12
# 2            [{'ee': 'kolm', 'grc': 'τρεῖς'}, {'ee': 'sest'...            16
# 3            [{'ee': 'ja', 'grc': 'καὶ'}, {'ee': 'mina', 'g...            47
# 4            [{'ee': 'kõige liikuvam', 'grc': 'κινητικώτατο...           457
# ...                                                        ...           ...
# 497          [{'grc': 'τούτων', 'ee': 'need [asjad]'}, {'gr...         37563
# 498          [{'grc': 'παλαιῶν', 'ee': 'vanadest'}, {'grc':...         11841
# 499          [{'grc': 'πανώλεθρος', 'ee': 'täiesti hukkunuk...          4533
# 500          [{'grc': 'ἐκ τῶν ... χρημάτων', 'ee': 'nende r...         14001
# 501          [{'grc': 'οὗτοι', 'ee': 'need'}, {'grc': 'εἰσὶ...          5585
#
#              grc_target_idx
# ee_sent_idx
# 0                         1
# 1                         4
# 2                         5
# 3                         6
# 4                         7
# ...                     ...
# 497                     526
# 498                     527
# 499                     528
# 500                     529
# 501                     530
#
# [502 rows x 5 columns]

# %%
grc_sent_idx = selected_sentence.name

# %%
df_words.loc[df_sents_ee.grc_target_idx]
# Out:
#                                                             index     text  \
# grc_target_idx
# 1                     καὶ [lemma: καί] (coordinating_conjunction)      καὶ
# 4                                         δὲ [lemma: δέ] (adverb)       δὲ
# 5                                       καὶ [lemma: καί] (adverb)      καὶ
# 6               τὴν [lemma: ὁ] (determiner) | singular.feminin...      τὴν
# 7                                     ἐν [lemma: ἐν] (adposition)       ἐν
# ...                                                           ...      ...
# 526             αὑτῶν [lemma: ἑαυτοῦ] (pronoun) | plural.mascu...    αὑτῶν
# 527             ἔργων [lemma: ἔργον] (noun) | plural.neuter.ge...    ἔργων
# 528             γένοιτο [lemma: γίγνομαι] (verb) | finite; pas...  γένοιτο
# 529             πολιτῶν [lemma: πολίτης] (noun) | plural.mascu...  πολιτῶν
# 530             οὗτοι [lemma: οὗτος] (adjective) | plural.masc...    οὗτοι
#
#                 count     lemma                       pos Aspect        Case  \
# grc_target_idx
# 1               76985       καί  coordinating_conjunction   None        None
# 4               26946        δέ                    adverb   None        None
# 5               21000       καί                    adverb   None        None
# 6               19781         ὁ                determiner   None  accusative
# 7               19662        ἐν                adposition   None        None
# ...               ...       ...                       ...    ...         ...
# 526               335    ἑαυτοῦ                   pronoun   None    genitive
# 527               334     ἔργον                      noun   None    genitive
# 528               334  γίγνομαι                      verb   None        None
# 529               334   πολίτης                      noun   None    genitive
# 530               334     οὗτος                 adjective   None  nominative
#
#                Definiteness Degree     Gender  ...    Number Person Polarity  \
# grc_target_idx                                 ...
# 1                      None   None       None  ...      None   None     None
# 4                      None   None       None  ...      None   None     None
# 5                      None   None       None  ...      None   None     None
# 6                      None   None   feminine  ...  singular   None     None
# 7                      None   None       None  ...      None   None     None
# ...                     ...    ...        ...  ...       ...    ...      ...
# 526                    None   None  masculine  ...    plural   None     None
# 527                    None   None     neuter  ...    plural   None     None
# 528                    None   None       None  ...  singular  third     None
# 529                    None   None  masculine  ...    plural   None     None
# 530                    None   None  masculine  ...    plural   None     None
#
#                Possessive PronominalType Reflexive Tense VerbForm   Voice  \
# grc_target_idx
# 1                    None           None      None  None     None    None
# 4                    None           None      None  None     None    None
# 5                    None           None      None  None     None    None
# 6                    None           None      None  None     None    None
# 7                    None           None      None  None     None    None
# ...                   ...            ...       ...   ...      ...     ...
# 526                  None           None      None  None     None    None
# 527                  None           None      None  None     None    None
# 528                  None           None      None  past   finite  middle
# 529                  None           None      None  None     None    None
# 530                  None           None      None  None     None    None
#
#                ee_sent_idx
# grc_target_idx
# 1                      0.0
# 4                      1.0
# 5                      2.0
# 6                      3.0
# 7                      4.0
# ...                    ...
# 526                  497.0
# 527                  498.0
# 528                  499.0
# 529                  500.0
# 530                  501.0
#
# [502 rows x 21 columns]

# %%
pd.merge(df_sents_ee, df_words, left_on="grc_target_idx", right_index=True)[["ee_phrase", "ee_target", "text"]]
# Out:
#                                                      ee_phrase  \
# ee_sent_idx
# 0            Ning need kirjalikud näidised loetakse teile e...
# 1                     Aga ka nende tunnistajaid toon ma teile.
# 2            Sest nad on kirja pannud igaühe [neist] kolm j...
# 3                   Ja mina imetlesin tema vastust ja ütlesin:
# 4                            See on looduses (kõige) liikuvam.
# ...                                                        ...
# 497          Aga kui need [asjad] olid tehtud, läksid nad t...
# 498                 Vanadest aga nüüd (olgu) töödest küllalt :
# 499             Täiesti hukkunuks [see] mitte kunagi ei saaks.
# 500           Ja nende rahade abil ma püüan kodanikke valvata.
# 501          Need on need esimesed, [kes] usu teenimist alu...
#
#                                             ee_target     text
# ee_sent_idx
# 0                                  ning [lemma: ning]      καὶ
# 1                                    aga [lemma: aga]       δὲ
# 2                               ja, isegi [lemma: ja]      καὶ
# 3                    selle (f. acc. sg.) [lemma: see]      τὴν
# 4                                -s, -l [lemma: sees]       ἐν
# ...                                               ...      ...
# 497                    oma (m. gen. pl.) [lemma: oma]    αὑτῶν
# 498                töödest (n. gen. pl.) [lemma: töö]    ἔργων
# 499                              saaks [lemma: saama]  γένοιτο
# 500          kodanikke (m. gen. pl.) [lemma: kodanik]  πολιτῶν
# 501                                 need [lemma: see]    οὗτοι
#
# [502 rows x 3 columns]

# %%
selected_sentence.name
# Out:
# 31

# %%
save_output(df_sents_ee=df_sents_ee, df_sents_grc=df_sents, df_words=df_words, grc_sent_idx=grc_sent_idx, grc_target_idx=grc_target_idx, parsed_msg_output=sentence_translation_dict)

# %%
df_sents_ee
# Out:
#                                                      ee_phrase  \
# ee_sent_idx
# 0            Aga [need] lepingud (apograafid) teile ette lo...
#
#                                       ee_target  \
# ee_sent_idx
# 0            loetakse ette [lemma: ette lugema]
#
#                                                       ee_words  grc_sent_idx  \
# ee_sent_idx
# 0            [{'grc': 'ἀναγνωσθήσονται', 'ee': 'loetakse et...            31
#
#              grc_target_idx
# ee_sent_idx
# 0                         1

# %%
save_output(df_sents_ee=df_sents_ee, df_sents_grc=df_sents, df_words=df_words, grc_sent_idx: int, grc_target_idx: int, parsed_msg_output=sentence_translation_dict)

# %%
type(selected_sentence_translation)
# Out:
# anthropic.types.message.Message

# %%
sentence_translation_dict = dict(json.loads(selected_sentence_translation.content[0].text))
sentence_translation_dict
# Out:
# {'lause': 'Aga [need] lepingud (apograafid) teile ette loetakse (tulevad loetud).',
#  'märksõna': 'loetakse ette [lemma: ette lugema]',
#  'tõlked': [{'grc': 'ἀναγνωσθήσονται', 'ee': 'loetakse ette'},
#   {'grc': 'δὲ', 'ee': 'aga'},
#   {'grc': 'ὑμῖν', 'ee': 'teile'},
#   {'grc': 'καὶ', 'ee': 'ja'},
#   {'grc': 'αὗται αἱ ἀπογραφαί', 'ee': 'need lepingud'}]}

# %%
msg_output = get_raw_translation(client, prompt_input)
parsed_msg_output = parse_output(msg_output)

# %%
# populate df_sents_ee
# first, make an ordering of words in df_words
# then iterate over the ordering. For first n=100 words,:
# get best matching sentence
# from this sentence, generate prompt
# from prompt, generate response
# store response in df_sents_ee with ref to sentence (grc_sent_idx) in df_sents and ref to word (grc_target_idx) in df_words
# update corresponding sentence in df_sents with ee_sent_idx
# update corresponding word in df_words with ee_sent_idx

# %%
#idx = 1
#matching_word = df_words.iloc[idx]
#print(matching_word["index"])
#matching_sents = find_matching_sentences(df_sents, word_hedrinks)
#matching_sents = filter_matching_sentences(matching_sents)

# %%
df_sents
# Out:
#         sentence_idx                                           metadata  \
# 0                  0  {'author': 'lysias', 'edition': 'Lysias with a...
# 1                  1  {'author': 'lysias', 'edition': 'Lysias with a...
# 2                  2  {'author': 'lysias', 'edition': 'Lysias with a...
# 3                  3  {'author': 'lysias', 'edition': 'Lysias with a...
# 4                  4  {'author': 'lysias', 'edition': 'Lysias with a...
# ...              ...                                                ...
# 121099        134639  {'author': 'homeric hymns', 'edition': 'Hymni ...
# 121100        134640  {'author': 'homeric hymns', 'edition': 'Hymni ...
# 121101        134641  {'author': 'homeric hymns', 'edition': 'Hymni ...
# 121102        134642  {'author': 'homeric hymns', 'edition': 'Hymni ...
# 121103        134643  {'author': 'homeric hymns', 'edition': 'Hymni ...
#
#                                              sentence_obj  \
# 0       [{'category': {'F': 'neg', 'N': 'pos', 'V': 'p...
# 1       [{'category': {'F': 'pos', 'N': 'pos', 'V': 'n...
# 2       [{'category': {'F': 'neg', 'N': 'neg', 'V': 'p...
# 3       [{'category': {'F': 'pos', 'N': 'neg', 'V': 'n...
# 4       [{'category': {'F': 'neg', 'N': 'neg', 'V': 'p...
# ...                                                   ...
# 121099  [{'category': {'F': 'neg', 'N': 'pos', 'V': 'p...
# 121100  [{'category': {'F': 'pos', 'N': 'pos', 'V': 'n...
# 121101  [{'category': {'F': 'pos', 'N': 'neg', 'V': 'n...
# 121102  [{'category': {'F': 'pos', 'N': None, 'V': Non...
# 121103  [{'category': {'F': 'neg', 'N': 'pos', 'V': 'p...
#
#                                              sentence_txt  len_words  \
# 0       ἴσως τινὲς ὑμῶν, ὦ ἄνδρες δικασταί, διὰ τὸ βού...         23
# 1       ἐγὼ δὲ τοσούτου δέω περὶ τῶν μὴ, προσηκόντων ἱ...         31
# 2       οἴμαι μὲν οὖν, ἐάν πάντα διηγήσωμαι τὰ πεπραγμ...         30
# 3                                  ἐξ ἀρχῆς οὖν ἀκούσατε.          5
# 4       ἐράτων ὁ Ἐρασιφῶντος πατὴρ ἐδανείσατο παρὰ τοῦ...         12
# ...                                                   ...        ...
# 121099  αἰδοίην, χρυσοστέφανον, καλὴν Ἀφροδίτην ᾁσομαι...         30
# 121100  τὴν δὲ χρυσάμπυκες Ὧραι δέξαντ ̓ ἀσπασίως, περ...         28
# 121101  ἐν δὲ τρητοῖσι λοβοῖσιν ἄνθεμ ̓ ὀρειχάλκου χρυ...         42
# 121102  αὐτὰρ ἐπειδὴ πάντα περὶ χροῒ κόσμον ἔθηκαν, ἦγ...         37
# 121103  χαῖρ ̓ ἑλικοβλέφαρε, γλυκυμείλιχε : δὸς δ ̓ ἐν...         21
#
#         len_chars ee_sent_idx
# 0             120        None
# 1             150        None
# 2             172        None
# 3              22        None
# 4              71        None
# ...           ...         ...
# 121099        184        None
# 121100        140        None
# 121101        242        None
# 121102        214        None
# 121103         98        None
#
# [121104 rows x 7 columns]
